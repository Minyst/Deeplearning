# %% [markdown]
# ![KakaoTalk_20230803_163633393.png](attachment:KakaoTalk_20230803_163633393.png)

# %% [markdown]
# # 기본 분류: 의류 이미지 분류

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow.keras import datasets, layers, Model

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2024-02-06 14:39:13.523637: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-06 14:39:14.216690: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvrtc.so.11.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/juing/app/TensorRT-7.2.3.4/lib:/usr/lib/nvidia:/home/juing/.mujoco/mujoco210/bin:/usr/local/cuda-11.2/extras/CUPTI/lib64:/usr/local/cuda-11.2/lib64
# 2024-02-06 14:39:14.216815: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvrtc.so.11.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/juing/app/TensorRT-7.2.3.4/lib:/usr/lib/nvidia:/home/juing/.mujoco/mujoco210/bin:/usr/local/cuda-11.2/extras/CUPTI/lib64:/usr/local/cuda-11.2/lib64
# 2024-02-06 14:39:14.216823: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2.11.0

# %% [markdown]
# ## CIFAR10 데이터셋 임포트하기

# %% [markdown]
# CIFAR10 데이터세트에는 10개 클래스에 60,000개의 컬러 이미지가 포함되어 있으며 각 클래스에는 6,000개의 이미지가 있습니다. 이 데이터세트는 50,000개의 훈련 이미지와 10,000개의 테스트 이미지로 나뉩니다. 클래스는 상호 배타적이며 서로 겹치지 않습니다.

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# ## 데이터 탐색
#
# 데이터세트가 올바른지 확인하기 위해 훈련 세트의 처음 25개 이미지를 플로팅하고 각 이미지 아래에 클래스 이름을 표시해 보겠습니다.

# %%
train_images.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# 비슷하게 훈련 세트에는 50,000개의 레이블이 있습니다:

# %%
len(train_labels)
# Out:
# 50000

# %% [markdown]
# 각 레이블은 0과 9사이의 정수입니다:

# %%
train_labels
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %% [markdown]
# 테스트 세트에는 10,000개의 이미지가 있습니다. 이 이미지도 32x32x3 픽셀로 표현됩니다:

# %%
test_images.shape
# Out:
# (10000, 32, 32, 3)

# %% [markdown]
# 테스트 세트는 10,000개의 이미지에 대한 레이블을 가지고 있습니다:

# %%
len(test_labels)
# Out:
# 10000

# %% [markdown]
# ## 데이터 전처리
#
# 네트워크를 훈련하기 전에 데이터를 전처리해야 합니다. 훈련 세트에 있는 첫 번째 이미지를 보면 픽셀 값의 범위가 0~1 사이라는 것을 알 수 있습니다:

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# 신경망 모델에 주입하기 전에 이 값의 범위를 0~1 사이로 조정하겠습니다. 이렇게 하려면 255로 나누어야 합니다. *훈련 세트*와 *테스트 세트*를 동일한 방식으로 전처리하는 것이 중요합니다:

# %%
train_images = train_images.astype(np.float32)
train_images = train_images / 255.0

test_images = test_images.astype(np.float32)
test_images = test_images / 255.0

# %%
train_labels = train_labels.astype(np.int32)
test_labels = test_labels.astype(np.int32)

# %% [markdown]
# *훈련 세트*에서 처음 25개 이미지와 그 아래 클래스 이름을 출력해 보죠. 데이터 포맷이 올바른지 확인하고 네트워크 구성과 훈련할 준비를 마칩니다.

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %% [markdown]
# ## data| augmentation
#
# 신경망 모델을 만들려면 모델의 층을 구성한 다음 모델을 컴파일합니다.

# %%
IMG_SIZE = 32 * 2

resize_and_rescale = tf.keras.Sequential([
  layers.Resizing(IMG_SIZE, IMG_SIZE),
])

# %%
result = resize_and_rescale(train_images[0])
_ = plt.imshow(result)

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
])

# %%
result = data_augmentation(train_images[0])
_ = plt.imshow(result)

# %%
def image_preprocess(image, label):
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, size=(IMG_SIZE, IMG_SIZE))
    label = tf.cast(label, tf.int32)
    return image, label

# %%
def image_augmentation(image, label, seed):
    # image = tf.image.resize_with_crop_or_pad(image, target_height=224, target_width=224)
    # image = tf.image.random_crop(image, size=(224, 224, 3))
    new_seed = tf.random.experimental.stateless_split(seed, num=1)[0, :]
    
    # Random crop back to the original size.
    image = tf.image.resize_with_crop_or_pad(image, int(IMG_SIZE*1.1), int(IMG_SIZE*1.1))
    image = tf.image.stateless_random_crop(image, size=[IMG_SIZE, IMG_SIZE, 3], seed=seed)
    
    # Random brightness.
    image = tf.image.stateless_random_brightness(image, max_delta=0.5, seed=new_seed)
    
    image = tf.clip_by_value(image, clip_value_min=0, clip_value_max=1)
    
    return image, label

# %%
# Create a generator.
rng = tf.random.Generator.from_seed(123, alg='philox')

# %%
# Create a wrapper function for updating seeds.
def wrapper_augmentation(image, label):
    seed = rng.make_seeds(2)[0]
    image, label = image_augmentation(image, label, seed)
    return image, label

# %% [markdown]
# ## Datasets

# %% [markdown]
# ### train datasets

# %%
datasets_train = tf.data.Dataset.from_tensor_slices((train_images, train_labels))

# %%
datasets_train = datasets_train.shuffle(buffer_size=len(train_labels))
datasets_train = datasets_train.map(image_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
datasets_train = datasets_train.map(wrapper_augmentation, num_parallel_calls=tf.data.AUTOTUNE)
datasets_train = datasets_train.batch(batch_size=32)
datasets_train = datasets_train.prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
plt.figure(figsize=(10,10))

images, labels = next(iter(datasets_train))

for i, (image, label) in enumerate(zip(images, labels)):
    
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(image)
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[int(label.numpy())])
    
    if i + 1 >= 25:
        break
    
plt.show()

# %% [markdown]
# ### test datasets

# %%
datasets_test = tf.data.Dataset.from_tensor_slices((test_images, test_labels))

# %%
datasets_test = datasets_test.map(image_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
datasets_test = datasets_test.batch(batch_size=32)
datasets_test = datasets_test.prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ## https://keras.io/api/applications/

# %% [markdown]
# Keras 애플리케이션은 사전 훈련된 가중치와 함께 사용할 수 있는 딥 러닝 모델입니다. 이러한 모델은 예측, 특징 추출 및 미세 조정에 사용될 수 있습니다.
#
# 모델을 인스턴스화할 때 가중치가 자동으로 다운로드됩니다. 에 저장되어 있습니다 ~/.keras/models/.
#
# 인스턴스화 시 Keras 구성 파일에 설정된 이미지 데이터 형식에 따라 모델이 구축됩니다 ~/.keras/keras.json. 예를 들어, 을 설정한 경우 image_data_format=channels_last이 저장소에서 로드된 모든 모델은 "높이-너비-깊이" 데이터 형식 규칙에 따라 구축됩니다.

# %% [markdown]
# <table>
# <thead>
# <tr>
# <th>Model</th>
# <th style="text-align: right;">Size (MB)</th>
# <th style="text-align: right;">Top-1 Accuracy</th>
# <th style="text-align: right;">Top-5 Accuracy</th>
# <th style="text-align: right;">Parameters</th>
# <th style="text-align: right;">Depth</th>
# <th style="text-align: right;">Time (ms) per inference step (CPU)</th>
# <th style="text-align: right;">Time (ms) per inference step (GPU)</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><a href="xception">Xception</a></td>
# <td style="text-align: right;">88</td>
# <td style="text-align: right;">79.0%</td>
# <td style="text-align: right;">94.5%</td>
# <td style="text-align: right;">22.9M</td>
# <td style="text-align: right;">81</td>
# <td style="text-align: right;">109.4</td>
# <td style="text-align: right;">8.1</td>
# </tr>
# <tr>
# <td><a href="vgg/#vgg16-function">VGG16</a></td>
# <td style="text-align: right;">528</td>
# <td style="text-align: right;">71.3%</td>
# <td style="text-align: right;">90.1%</td>
# <td style="text-align: right;">138.4M</td>
# <td style="text-align: right;">16</td>
td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="efficientnet_v2/#efficientnetv2b3-function">EfficientNetV2B3</a></td>
# <td style="text-align: right;">59</td>
# <td style="text-align: right;">82.0%</td>
# <td style="text-align: right;">95.8%</td>
# <td style="text-align: right;">14.5M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="efficientnet_v2/#efficientnetv2s-function">EfficientNetV2S</a></td>
# <td style="text-align: right;">88</td>
# <td style="text-align: right;">83.9%</td>
# <td style="text-align: right;">96.7%</td>
# <td style="text-align: right;">21.6M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="efficientnet_v2/#efficientnetv2m-function">EfficientNetV2M</a></td>
# <td style="text-align: right;">220</td>
# <td style="text-align: right;">85.3%</td>
# <td style="text-align: right;">97.4%</td>
# <td style="text-align: right;">54.4M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="efficientnet_v2/#efficientnetv2l-function">EfficientNetV2L</a></td>
# <td style="text-align: right;">479</td>
# <td style="text-align: right;">85.7%</td>
# <td style="text-align: right;">97.5%</td>
# <td style="text-align: right;">119.0M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="convnext/#convnexttiny-function">ConvNeXtTiny</a></td>
# <td style="text-align: right;">109.42</td>
# <td style="text-align: right;">81.3%</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">28.6M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="convnext/#convnextsmall-function">ConvNeXtSmall</a></td>
# <td style="text-align: right;">192.29</td>
# <td style="text-align: right;">82.3%</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">50.2M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="convnext/#convnextbase-function">ConvNeXtBase</a></td>
# <td style="text-align: right;">338.58</td>
# <td style="text-align: right;">85.3%</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">88.5M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="convnext/#convnextlarge-function">ConvNeXtLarge</a></td>
# <td style="text-align: right;">755.07</td>
# <td style="text-align: right;">86.3%</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">197.7M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="convnext/#convnextxlarge-function">ConvNeXtXLarge</a></td>
# <td style="text-align: right;">1310</td>
# <td style="text-align: right;">86.7%</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">350.1M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ### 층 설정
#
# 신경망의 기본 빌딩 블록은 [*레이어*](https://www.tensorflow.org/api_docs/python/tf/keras/layers) 입니다. 레이어는 레이어에 공급된 데이터로부터 표현을 추출합니다. 이러한 표현은 당면한 문제에 의미가 있어야 합니다.
#
# 대부분 딥러닝은 간단한 층을 연결하여 구성됩니다. `tf.keras.layers.Dense`와 같은 층들의 가중치(parameter)는 훈련하는 동안 학습됩니다.

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/applications

# %%
input_shape = (IMG_SIZE, IMG_SIZE, 3)

# %%
MobileNetV2 = tf.keras.applications.MobileNetV2(
    input_shape=input_shape,
    include_top=False,
    weights=None
)

# %%
inputs = MobileNetV2.input

# %%
x = MobileNetV2.output

# %%
x = layers.GlobalAveragePooling2D()(x)

# %%
x
# Out:
# <KerasTensor: shape=(None, 1280) dtype=float32 (created by layer 'global_average_pooling2d')>

# %%
x = layers.LayerNormalization()(x)

# %%
x
# Out:
# <KerasTensor: shape=(None, 1280) dtype=float32 (created by layer 'layer_normalization')>

# %%
outputs = layers.Dense(len(class_names), activation='softmax')(x)

# %%
outputs
# Out:
# <KerasTensor: shape=(None, 10) dtype=float32 (created by layer 'dense')>

# %%
model = Model(inputs=inputs, outputs=outputs)

# %%
model.summary(show_trainable=True)
# Out:
# Model: "model"
# _____________________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to                     Trainable
# =============================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []                               Y
#
#  Conv1 (Conv2D)                 (None, 32, 32, 32)   864         ['input_1[0][0]']                Y
#
#  bn_Conv1 (BatchNormalization)  (None, 32, 32, 32)   128         ['Conv1[0][0]']                  Y
#
#  Conv1_relu (ReLU)              (None, 32, 32, 32)   0           ['bn_Conv1[0][0]']               Y
#
#  expanded_conv_depthwise (Depth  (None, 32, 32, 32)  288         ['Conv1_relu[0][0]']             Y
#  wiseConv2D)
#
#  expanded_conv_depthwise_BN (Ba  (None, 32, 32, 32)  128         ['expanded_conv_depthwise[0][0]  Y
#  tchNormalization)                                               ']
#
#  expanded_conv_depthwise_relu (  (None, 32, 32, 32)  0           ['expanded_conv_depthwise_BN[0]  Y
#  ReLU)                                                           [0]']
#
#  expanded_conv_project (Conv2D)  (None, 32, 32, 16)  512         ['expanded_conv_depthwise_relu[  Y
#                                                                  0][0]']
#
#  expanded_conv_project_BN (Batc  (None, 32, 32, 16)  64          ['expanded_conv_project[0][0]']  Y
#  hNormalization)
#
#  block_1_expand (Conv2D)        (None, 32, 32, 96)   1536        ['expanded_conv_project_BN[0][0  Y
#                                                                  ]']
#
#  block_1_expand_BN (BatchNormal  (None, 32, 32, 96)  384         ['block_1_expand[0][0]']         Y
#  ization)
#
#  block_1_expand_relu (ReLU)     (None, 32, 32, 96)   0           ['block_1_expand_BN[0][0]']      Y
#
#  block_1_pad (ZeroPadding2D)    (None, 33, 33, 96)   0           ['block_1_expand_relu[0][0]']    Y
#
#  block_1_depthwise (DepthwiseCo  (None, 16, 16, 96)  864         ['block_1_pad[0][0]']            Y
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 16, 16, 96)  384         ['block_1_depthwise[0][0]']      Y
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 16, 16, 96)   0           ['block_1_depthwise_BN[0][0]']   Y
#
#  block_1_project (Conv2D)       (None, 16, 16, 24)   2304        ['block_1_depthwise_relu[0][0]'  Y
#                                                                  ]
#
#  block_1_project_BN (BatchNorma  (None, 16, 16, 24)  96          ['block_1_project[0][0]']        Y
#  lization)
#
#  block_2_expand (Conv2D)        (None, 16, 16, 144)  3456        ['block_1_project_BN[0][0]']     Y
#
#  block_2_expand_BN (BatchNormal  (None, 16, 16, 144)  576        ['block_2_expand[0][0]']         Y
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 16, 16, 144)  0           ['block_2_expand_BN[0][0]']      Y
#
#  block_2_depthwise (DepthwiseCo  (None, 16, 16, 144)  1296       ['block_2_expand_relu[0][0]']    Y
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 16, 16, 144)  576        ['block_2_depthwise[0][0]']      Y
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 16, 16, 144)  0           ['block_2_depthwise_BN[0][0]']   Y
#
#  block_2_project (Conv2D)       (None, 16, 16, 24)   3456        ['block_2_depthwise_relu[0][0]'  Y
#                                                                  ]
#
#  block_2_project_BN (BatchNorma  (None, 16, 16, 24)  96          ['block_2_project[0][0]']        Y
#  lization)
#
#  block_2_add (Add)              (None, 16, 16, 24)   0           ['block_1_project_BN[0][0]',     Y
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 16, 16, 144)  3456        ['block_2_add[0][0]']            Y
#
#  block_3_expand_BN (BatchNormal  (None, 16, 16, 144)  576        ['block_3_expand[0][0]']         Y
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 16, 16, 144)  0           ['block_3_expand_BN[0][0]']      Y
#
#  block_3_pad (ZeroPadding2D)    (None, 17, 17, 144)  0           ['block_3_expand_relu[0][0]']    Y
#
#  block_3_depthwise (DepthwiseCo  (None, 8, 8, 144)   1296        ['block_3_pad[0][0]']            Y
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 8, 8, 144)   576         ['block_3_depthwise[0][0]']      Y
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 8, 8, 144)    0           ['block_3_depthwise_BN[0][0]']   Y
#
#  block_3_project (Conv2D)       (None, 8, 8, 32)     4608        ['block_3_depthwise_relu[0][0]'  Y
#                                                                  ]
#
#  block_3_project_BN (BatchNorma  (None, 8, 8, 32)    128         ['block_3_project[0][0]']        Y
#  lization)
#
#  block_4_expand (Conv2D)        (None, 8, 8, 192)    6144        ['block_3_project_BN[0][0]']     Y
#
#  block_4_expand_BN (BatchNormal  (None, 8, 8, 192)   768         ['block_4_expand[0][0]']         Y
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 8, 8, 192)    0           ['block_4_expand_BN[0][0]']      Y
#
#  block_4_depthwise (DepthwiseCo  (None, 8, 8, 192)   1728        ['block_4_expand_relu[0][0]']    Y
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 8, 8, 192)   768         ['block_4_depthwise[0][0]']      Y
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 8, 8, 192)    0           ['block_4_depthwise_BN[0][0]']   Y
#
#  block_4_project (Conv2D)       (None, 8, 8, 32)     6144        ['block_4_depthwise_relu[0][0]'  Y
#                                                                  ]
#
#  block_4_project_BN (BatchNorma  (None, 8, 8, 32)    128         ['block_4_project[0][0]']        Y
#  lization)
#
#  block_4_add (Add)              (None, 8, 8, 32)     0           ['block_3_project_BN[0][0]',     Y
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 8, 8, 192)    6144        ['block_4_add[0][0]']            Y
#
#  block_5_expand_BN (BatchNormal  (None, 8, 8, 192)   768         ['block_5_expand[0][0]']         Y
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 8, 8, 192)    0           ['block_5_expand_BN[0][0]']      Y
#
#  block_5_depthwise (DepthwiseCo  (None, 8, 8, 192)   1728        ['block_5_expand_relu[0][0]']    Y
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 8, 8, 192)   768         ['block_5_depthwise[0][0]']      Y
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 8, 8, 192)    0           ['block_5_depthwise_BN[0][0]']   Y
#
#  block_5_project (Conv2D)       (None, 8, 8, 32)     6144        ['block_5_depthwise_relu[0][0]'  Y
#                                                                  ]
#
#  block_5_project_BN (BatchNorma  (None, 8, 8, 32)    128         ['block_5_project[0][0]']        Y
#  lization)
#
#  block_5_add (Add)              (None, 8, 8, 32)     0           ['block_4_add[0][0]',            Y
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 8, 8, 192)    6144        ['block_5_add[0][0]']            Y
#
#  block_6_expand_BN (BatchNormal  (None, 8, 8, 192)   768         ['block_6_expand[0][0]']         Y
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 8, 8, 192)    0           ['block_6_expand_BN[0][0]']      Y
#
#  block_6_pad (ZeroPadding2D)    (None, 9, 9, 192)    0           ['block_6_expand_relu[0][0]']    Y
#
#  block_6_depthwise (DepthwiseCo  (None, 4, 4, 192)   1728        ['block_6_pad[0][0]']            Y
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 4, 4, 192)   768         ['block_6_depthwise[0][0]']      Y
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 4, 4, 192)    0           ['block_6_depthwise_BN[0][0]']   Y
#
#  block_6_project (Conv2D)       (None, 4, 4, 64)     12288       ['block_6_depthwise_relu[0][0]'  Y
#                                                                  ]
#
#  block_6_project_BN (BatchNorma  (None, 4, 4, 64)    256         ['block_6_project[0][0]']        Y
#  lization)
#
#  block_7_expand (Conv2D)        (None, 4, 4, 384)    24576       ['block_6_project_BN[0][0]']     Y
#
#  block_7_expand_BN (BatchNormal  (None, 4, 4, 384)   1536        ['block_7_expand[0][0]']         Y
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 4, 4, 384)    0           ['block_7_expand_BN[0][0]']      Y
#
#  block_7_depthwise (DepthwiseCo  (None, 4, 4, 384)   3456        ['block_7_expand_relu[0][0]']    Y
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 4, 4, 384)   1536        ['block_7_depthwise[0][0]']      Y
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 4, 4, 384)    0           ['block_7_depthwise_BN[0][0]']   Y
#
#  block_7_project (Conv2D)       (None, 4, 4, 64)     24576       ['block_7_depthwise_relu[0][0]'  Y
#                                                                  ]
#
#  block_7_project_BN (BatchNorma  (None, 4, 4, 64)    256         ['block_7_project[0][0]']        Y
#  lization)
#
#  block_7_add (Add)              (None, 4, 4, 64)     0           ['block_6_project_BN[0][0]',     Y
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 4, 4, 384)    24576       ['block_7_add[0][0]']            Y
#
#  block_8_expand_BN (BatchNormal  (None, 4, 4, 384)   1536        ['block_8_expand[0][0]']         Y
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 4, 4, 384)    0           ['block_8_expand_BN[0][0]']      Y
#
#  block_8_depthwise (DepthwiseCo  (None, 4, 4, 384)   3456        ['block_8_expand_relu[0][0]']    Y
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 4, 4, 384)   1536        ['block_8_depthwise[0][0]']      Y
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 4, 4, 384)    0           ['block_8_depthwise_BN[0][0]']   Y
#
#  block_8_project (Conv2D)       (None, 4, 4, 64)     24576       ['block_8_depthwise_relu[0][0]'  Y
#                                                                  ]
#
#  block_8_project_BN (BatchNorma  (None, 4, 4, 64)    256         ['block_8_project[0][0]']        Y
#  lization)
#
#  block_8_add (Add)              (None, 4, 4, 64)     0           ['block_7_add[0][0]',            Y
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 4, 4, 384)    24576       ['block_8_add[0][0]']            Y
#
#  block_9_expand_BN (BatchNormal  (None, 4, 4, 384)   1536        ['block_9_expand[0][0]']         Y
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 4, 4, 384)    0           ['block_9_expand_BN[0][0]']      Y
#
#  block_9_depthwise (DepthwiseCo  (None, 4, 4, 384)   3456        ['block_9_expand_relu[0][0]']    Y
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 4, 4, 384)   1536        ['block_9_depthwise[0][0]']      Y
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 4, 4, 384)    0           ['block_9_depthwise_BN[0][0]']   Y
#
#  block_9_project (Conv2D)       (None, 4, 4, 64)     24576       ['block_9_depthwise_relu[0][0]'  Y
#                                                                  ]
#
#  block_9_project_BN (BatchNorma  (None, 4, 4, 64)    256         ['block_9_project[0][0]']        Y
#  lization)
#
#  block_9_add (Add)              (None, 4, 4, 64)     0           ['block_8_add[0][0]',            Y
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 4, 4, 384)    24576       ['block_9_add[0][0]']            Y
#
#  block_10_expand_BN (BatchNorma  (None, 4, 4, 384)   1536        ['block_10_expand[0][0]']        Y
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 4, 4, 384)    0           ['block_10_expand_BN[0][0]']     Y
#
#  block_10_depthwise (DepthwiseC  (None, 4, 4, 384)   3456        ['block_10_expand_relu[0][0]']   Y
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 4, 4, 384)   1536        ['block_10_depthwise[0][0]']     Y
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 4, 4, 384)   0           ['block_10_depthwise_BN[0][0]']  Y
#
#  block_10_project (Conv2D)      (None, 4, 4, 96)     36864       ['block_10_depthwise_relu[0][0]  Y
#                                                                  ']
#
#  block_10_project_BN (BatchNorm  (None, 4, 4, 96)    384         ['block_10_project[0][0]']       Y
#  alization)
#
#  block_11_expand (Conv2D)       (None, 4, 4, 576)    55296       ['block_10_project_BN[0][0]']    Y
#
#  block_11_expand_BN (BatchNorma  (None, 4, 4, 576)   2304        ['block_11_expand[0][0]']        Y
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 4, 4, 576)    0           ['block_11_expand_BN[0][0]']     Y
#
#  block_11_depthwise (DepthwiseC  (None, 4, 4, 576)   5184        ['block_11_expand_relu[0][0]']   Y
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 4, 4, 576)   2304        ['block_11_depthwise[0][0]']     Y
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 4, 4, 576)   0           ['block_11_depthwise_BN[0][0]']  Y
#
#  block_11_project (Conv2D)      (None, 4, 4, 96)     55296       ['block_11_depthwise_relu[0][0]  Y
#                                                                  ']
#
#  block_11_project_BN (BatchNorm  (None, 4, 4, 96)    384         ['block_11_project[0][0]']       Y
#  alization)
#
#  block_11_add (Add)             (None, 4, 4, 96)     0           ['block_10_project_BN[0][0]',    Y
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 4, 4, 576)    55296       ['block_11_add[0][0]']           Y
#
#  block_12_expand_BN (BatchNorma  (None, 4, 4, 576)   2304        ['block_12_expand[0][0]']        Y
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 4, 4, 576)    0           ['block_12_expand_BN[0][0]']     Y
#
#  block_12_depthwise (DepthwiseC  (None, 4, 4, 576)   5184        ['block_12_expand_relu[0][0]']   Y
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 4, 4, 576)   2304        ['block_12_depthwise[0][0]']     Y
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 4, 4, 576)   0           ['block_12_depthwise_BN[0][0]']  Y
#
#  block_12_project (Conv2D)      (None, 4, 4, 96)     55296       ['block_12_depthwise_relu[0][0]  Y
#                                                                  ']
#
#  block_12_project_BN (BatchNorm  (None, 4, 4, 96)    384         ['block_12_project[0][0]']       Y
#  alization)
#
#  block_12_add (Add)             (None, 4, 4, 96)     0           ['block_11_add[0][0]',           Y
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 4, 4, 576)    55296       ['block_12_add[0][0]']           Y
#
#  block_13_expand_BN (BatchNorma  (None, 4, 4, 576)   2304        ['block_13_expand[0][0]']        Y
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 4, 4, 576)    0           ['block_13_expand_BN[0][0]']     Y
#
#  block_13_pad (ZeroPadding2D)   (None, 5, 5, 576)    0           ['block_13_expand_relu[0][0]']   Y
#
#  block_13_depthwise (DepthwiseC  (None, 2, 2, 576)   5184        ['block_13_pad[0][0]']           Y
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 2, 2, 576)   2304        ['block_13_depthwise[0][0]']     Y
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 2, 2, 576)   0           ['block_13_depthwise_BN[0][0]']  Y
#
#  block_13_project (Conv2D)      (None, 2, 2, 160)    92160       ['block_13_depthwise_relu[0][0]  Y
#                                                                  ']
#
#  block_13_project_BN (BatchNorm  (None, 2, 2, 160)   640         ['block_13_project[0][0]']       Y
#  alization)
#
#  block_14_expand (Conv2D)       (None, 2, 2, 960)    153600      ['block_13_project_BN[0][0]']    Y
#
#  block_14_expand_BN (BatchNorma  (None, 2, 2, 960)   3840        ['block_14_expand[0][0]']        Y
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 2, 2, 960)    0           ['block_14_expand_BN[0][0]']     Y
#
#  block_14_depthwise (DepthwiseC  (None, 2, 2, 960)   8640        ['block_14_expand_relu[0][0]']   Y
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 2, 2, 960)   3840        ['block_14_depthwise[0][0]']     Y
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 2, 2, 960)   0           ['block_14_depthwise_BN[0][0]']  Y
#
#  block_14_project (Conv2D)      (None, 2, 2, 160)    153600      ['block_14_depthwise_relu[0][0]  Y
#                                                                  ']
#
#  block_14_project_BN (BatchNorm  (None, 2, 2, 160)   640         ['block_14_project[0][0]']       Y
#  alization)
#
#  block_14_add (Add)             (None, 2, 2, 160)    0           ['block_13_project_BN[0][0]',    Y
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 2, 2, 960)    153600      ['block_14_add[0][0]']           Y
#
#  block_15_expand_BN (BatchNorma  (None, 2, 2, 960)   3840        ['block_15_expand[0][0]']        Y
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 2, 2, 960)    0           ['block_15_expand_BN[0][0]']     Y
#
#  block_15_depthwise (DepthwiseC  (None, 2, 2, 960)   8640        ['block_15_expand_relu[0][0]']   Y
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 2, 2, 960)   3840        ['block_15_depthwise[0][0]']     Y
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 2, 2, 960)   0           ['block_15_depthwise_BN[0][0]']  Y
#
#  block_15_project (Conv2D)      (None, 2, 2, 160)    153600      ['block_15_depthwise_relu[0][0]  Y
#                                                                  ']
#
#  block_15_project_BN (BatchNorm  (None, 2, 2, 160)   640         ['block_15_project[0][0]']       Y
#  alization)
#
#  block_15_add (Add)             (None, 2, 2, 160)    0           ['block_14_add[0][0]',           Y
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 2, 2, 960)    153600      ['block_15_add[0][0]']           Y
#
#  block_16_expand_BN (BatchNorma  (None, 2, 2, 960)   3840        ['block_16_expand[0][0]']        Y
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 2, 2, 960)    0           ['block_16_expand_BN[0][0]']     Y
#
#  block_16_depthwise (DepthwiseC  (None, 2, 2, 960)   8640        ['block_16_expand_relu[0][0]']   Y
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 2, 2, 960)   3840        ['block_16_depthwise[0][0]']     Y
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 2, 2, 960)   0           ['block_16_depthwise_BN[0][0]']  Y
#
#  block_16_project (Conv2D)      (None, 2, 2, 320)    307200      ['block_16_depthwise_relu[0][0]  Y
#                                                                  ']
#
#  block_16_project_BN (BatchNorm  (None, 2, 2, 320)   1280        ['block_16_project[0][0]']       Y
#  alization)
#
#  Conv_1 (Conv2D)                (None, 2, 2, 1280)   409600      ['block_16_project_BN[0][0]']    Y
#
#  Conv_1_bn (BatchNormalization)  (None, 2, 2, 1280)  5120        ['Conv_1[0][0]']                 Y
#
#  out_relu (ReLU)                (None, 2, 2, 1280)   0           ['Conv_1_bn[0][0]']              Y
#
#  global_average_pooling2d (Glob  (None, 1280)        0           ['out_relu[0][0]']               Y
#  alAveragePooling2D)
#
#  layer_normalization (LayerNorm  (None, 1280)        2560        ['global_average_pooling2d[0][0  Y
#  alization)                                                      ]']
#
#  dense (Dense)                  (None, 10)           12810       ['layer_normalization[0][0]']    Y
#
# =============================================================================================================
# Total params: 2,273,354
# Trainable params: 2,239,242
# Non-trainable params: 34,112
# _____________________________________________________________________________________________________________

# %% [markdown]
# ### 모델 컴파일
#
# 모델을 훈련할 준비가 되기 전에 몇 가지 설정이 더 필요합니다. 다음은 모델의 [*컴파일*](https://www.tensorflow.org/api_docs/python/tf/keras/Model#compile) 단계에서 추가됩니다.
#
# - [*손실 함수*](https://www.tensorflow.org/api_docs/python/tf/keras/losses) - 훈련 중 모델이 얼마나 정확한지 측정합니다. 모델을 올바른 방향으로 "조정"하려면 이 함수를 최소화해야 합니다.
# - [*옵티마이저*](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers) - 모델이 인식하는 데이터와 해당 손실 함수를 기반으로 모델이 업데이트되는 방식입니다.
# - [*메트릭*](https://www.tensorflow.org/api_docs/python/tf/keras/metrics) — 훈련 및 테스트 단계를 모니터링하는 데 사용됩니다. 다음 예에서는 올바르게 분류된 이미지의 비율인 *정확도*를 사용합니다.

# %%
model.compile(optimizer=tf.optimizers.Adam(learning_rate=1e-03),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=[
                  tf.keras.metrics.SparseCategoricalAccuracy()
              ])

# %% [markdown]
# ## 모델 훈련
#
# 신경망 모델을 훈련하려면 다음 단계가 필요합니다.
#
# 1. 훈련 데이터를 모델에 주입합니다-이 예에서는 `train_images`와 `train_labels` 배열입니다.
# 2. 모델이 이미지와 레이블을 매핑하는 방법을 배웁니다.
# 3. 테스트 세트에 대한 모델의 예측을 만듭니다-이 예에서는 `test_images` 배열입니다. 이 예측이 `test_labels` 배열의 레이블과 맞는지 확인합니다.
# 4. 예측이 `test_labels` 배열의 레이블과 일치하는지 확인합니다.

# %% [markdown]
# ### 모델 피드
#
# 훈련을 시작하려면 [`model.fit`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit) 메서드를 호출합니다. 모델을 훈련 데이터에 "맞추기(fit)" 때문에 이렇게 불립니다.

# %%
history  = model.fit(datasets_train, epochs=50, validation_data=datasets_test)
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 69s 31ms/step - loss: 2.0935 - sparse_categorical_accuracy: 0.2574 - val_loss: 2.8879 - val_sparse_categorical_accuracy: 0.1000
# Epoch 2/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7407 - sparse_categorical_accuracy: 0.3754 - val_loss: 2.5797 - val_sparse_categorical_accuracy: 0.1000
# Epoch 3/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.5475 - sparse_categorical_accuracy: 0.4514 - val_loss: 2.3282 - val_sparse_categorical_accuracy: 0.2317
# Epoch 4/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.4008 - sparse_categorical_accuracy: 0.5040 - val_loss: 2.3646 - val_sparse_categorical_accuracy: 0.3522
# Epoch 5/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.2435 - sparse_categorical_accuracy: 0.5630 - val_loss: 2.3280 - val_sparse_categorical_accuracy: 0.4614
# Epoch 6/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.0540 - sparse_categorical_accuracy: 0.6304 - val_loss: 2.4571 - val_sparse_categorical_accuracy: 0.4266
# Epoch 7/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.9766 - sparse_categorical_accuracy: 0.6615 - val_loss: 1.8554 - val_sparse_categorical_accuracy: 0.4774
# Epoch 8/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.8861 - sparse_categorical_accuracy: 0.6928 - val_loss: 1.5952 - val_sparse_categorical_accuracy: 0.5674
# Epoch 9/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.8318 - sparse_categorical_accuracy: 0.7101 - val_loss: 1.6120 - val_sparse_categorical_accuracy: 0.5896
# Epoch 10/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.7709 - sparse_categorical_accuracy: 0.7329 - val_loss: 1.4913 - val_sparse_categorical_accuracy: 0.6430
# Epoch 11/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.7330 - sparse_categorical_accuracy: 0.7471 - val_loss: 1.1878 - val_sparse_categorical_accuracy: 0.6651
# Epoch 12/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.7133 - sparse_categorical_accuracy: 0.7554 - val_loss: 1.0537 - val_sparse_categorical_accuracy: 0.6893
# Epoch 13/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.6907 - sparse_categorical_accuracy: 0.7624 - val_loss: 0.9388 - val_sparse_categorical_accuracy: 0.7143
# Epoch 14/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.6727 - sparse_categorical_accuracy: 0.7681 - val_loss: 1.1875 - val_sparse_categorical_accuracy: 0.6568
# Epoch 15/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.6145 - sparse_categorical_accuracy: 0.7873 - val_loss: 0.9830 - val_sparse_categorical_accuracy: 0.7010
# Epoch 16/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.6099 - sparse_categorical_accuracy: 0.7868 - val_loss: 0.7504 - val_sparse_categorical_accuracy: 0.7635
# Epoch 17/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.5787 - sparse_categorical_accuracy: 0.8001 - val_loss: 0.6933 - val_sparse_categorical_accuracy: 0.7753
# Epoch 18/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.5477 - sparse_categorical_accuracy: 0.8072 - val_loss: 0.7551 - val_sparse_categorical_accuracy: 0.7691
# Epoch 19/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.5369 - sparse_categorical_accuracy: 0.8127 - val_loss: 0.7506 - val_sparse_categorical_accuracy: 0.7619
# Epoch 20/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.5179 - sparse_categorical_accuracy: 0.8208 - val_loss: 0.7294 - val_sparse_categorical_accuracy: 0.7629
# Epoch 21/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.5119 - sparse_categorical_accuracy: 0.8210 - val_loss: 0.7059 - val_sparse_categorical_accuracy: 0.7865
# Epoch 22/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4821 - sparse_categorical_accuracy: 0.8332 - val_loss: 0.6268 - val_sparse_categorical_accuracy: 0.8004
# Epoch 23/50
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.4802 - sparse_categorical_accuracy: 0.8330 - val_loss: 0.7071 - val_sparse_categorical_accuracy: 0.7884
# Epoch 24/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4694 - sparse_categorical_accuracy: 0.8378 - val_loss: 0.5943 - val_sparse_categorical_accuracy: 0.8163
# Epoch 25/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4365 - sparse_categorical_accuracy: 0.8505 - val_loss: 0.5818 - val_sparse_categorical_accuracy: 0.8145
# Epoch 26/50
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.4184 - sparse_categorical_accuracy: 0.8536 - val_loss: 0.6009 - val_sparse_categorical_accuracy: 0.8180
# Epoch 27/50
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.4334 - sparse_categorical_accuracy: 0.8495 - val_loss: 0.5551 - val_sparse_categorical_accuracy: 0.8221
# Epoch 28/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.4075 - sparse_categorical_accuracy: 0.8573 - val_loss: 0.5809 - val_sparse_categorical_accuracy: 0.8184
# Epoch 29/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.3948 - sparse_categorical_accuracy: 0.8620 - val_loss: 0.8584 - val_sparse_categorical_accuracy: 0.7595
# Epoch 30/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.3852 - sparse_categorical_accuracy: 0.8648 - val_loss: 0.6115 - val_sparse_categorical_accuracy: 0.8090
# Epoch 31/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.3656 - sparse_categorical_accuracy: 0.8718 - val_loss: 0.5914 - val_sparse_categorical_accuracy: 0.8210
# Epoch 32/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.3816 - sparse_categorical_accuracy: 0.8664 - val_loss: 0.6893 - val_sparse_categorical_accuracy: 0.7907
# Epoch 33/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.3560 - sparse_categorical_accuracy: 0.8778 - val_loss: 0.6346 - val_sparse_categorical_accuracy: 0.8210
# Epoch 34/50
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.3450 - sparse_categorical_accuracy: 0.8785 - val_loss: 0.5952 - val_sparse_categorical_accuracy: 0.8197
# Epoch 35/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.3471 - sparse_categorical_accuracy: 0.8788 - val_loss: 0.5503 - val_sparse_categorical_accuracy: 0.8288
# Epoch 36/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.3264 - sparse_categorical_accuracy: 0.8851 - val_loss: 0.5836 - val_sparse_categorical_accuracy: 0.8241
# Epoch 37/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.3209 - sparse_categorical_accuracy: 0.8872 - val_loss: 0.5838 - val_sparse_categorical_accuracy: 0.8241
# Epoch 38/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.3131 - sparse_categorical_accuracy: 0.8915 - val_loss: 0.6343 - val_sparse_categorical_accuracy: 0.8210
# Epoch 39/50
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.3083 - sparse_categorical_accuracy: 0.8914 - val_loss: 0.6182 - val_sparse_categorical_accuracy: 0.8188
# Epoch 40/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.3039 - sparse_categorical_accuracy: 0.8927 - val_loss: 0.6622 - val_sparse_categorical_accuracy: 0.8080
# Epoch 41/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.3115 - sparse_categorical_accuracy: 0.8919 - val_loss: 0.5846 - val_sparse_categorical_accuracy: 0.8229
# Epoch 42/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.3159 - sparse_categorical_accuracy: 0.8881 - val_loss: 0.5718 - val_sparse_categorical_accuracy: 0.8312
# Epoch 43/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.2990 - sparse_categorical_accuracy: 0.8948 - val_loss: 0.6676 - val_sparse_categorical_accuracy: 0.8109
# Epoch 44/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.2740 - sparse_categorical_accuracy: 0.9039 - val_loss: 0.5616 - val_sparse_categorical_accuracy: 0.8347
# Epoch 45/50
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.2757 - sparse_categorical_accuracy: 0.9032 - val_loss: 0.7036 - val_sparse_categorical_accuracy: 0.8055
# Epoch 46/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.2678 - sparse_categorical_accuracy: 0.9057 - val_loss: 0.5909 - val_sparse_categorical_accuracy: 0.8311
# Epoch 47/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.2555 - sparse_categorical_accuracy: 0.9091 - val_loss: 0.5665 - val_sparse_categorical_accuracy: 0.8407
# Epoch 48/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.2690 - sparse_categorical_accuracy: 0.9051 - val_loss: 0.5629 - val_sparse_categorical_accuracy: 0.8375
# Epoch 49/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.2520 - sparse_categorical_accuracy: 0.9113 - val_loss: 0.5904 - val_sparse_categorical_accuracy: 0.8256
# Epoch 50/50
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.2489 - sparse_categorical_accuracy: 0.9129 - val_loss: 0.5772 - val_sparse_categorical_accuracy: 0.8359

# %% [markdown]
# 모델이 훈련되면서 손실과 정확도 지표가 출력됩니다. 이 모델은 훈련 세트에서 약 0.88(88%) 정도의 정확도를 달성합니다.

# %% [markdown]
# ### 정확도 평가
#
# 다음으로, 모델이 테스트 데이터세트에서 작동하는 방식을 비교합니다.

# %%
test_loss, test_acc = model.evaluate(datasets_test, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 2s - loss: 0.5772 - sparse_categorical_accuracy: 0.8359 - 2s/epoch - 8ms/step
#
# Test accuracy: 0.8359000086784363

# %% [markdown]
# 테스트 세트의 정확도가 훈련 세트의 정확도보다 조금 낮습니다. 훈련 세트의 정확도와 테스트 세트의 정확도 사이의 차이는 *과대적합*(overfitting) 때문입니다. 과대적합은 머신러닝 모델이 훈련 데이터보다 새로운 데이터에서 성능이 낮아지는 현상을 말합니다.
#
# - 과대적합 시연
# - 과대적합을 방지하기 위한 전략

# %% [markdown]
# ### 예측하기
#
# 훈련된 모델을 사용하여 일부 이미지에 대한 예측을 수행할 수 있습니다.

# %%
predictions = model.predict(datasets_test)
# Out:
# 313/313 [==============================] - 3s 7ms/step

# %% [markdown]
# 여기서는 테스트 세트에 있는 각 이미지의 레이블을 예측했습니다. 첫 번째 예측을 확인해 보죠:

# %%
predictions[0]
# Out:
# array([1.4383398e-06, 5.5049372e-07, 1.7270886e-05, 9.9803883e-01,
#        1.9178988e-06, 1.9290638e-03, 8.5128358e-06, 5.1700437e-07,
#        1.2390883e-06, 6.6003258e-07], dtype=float32)

# %% [markdown]
# 이 예측은 10개의 숫자 배열로 나타납니다. 이 값은 10개의 옷 품목에 상응하는 모델의 신뢰도(confidence)를 나타냅니다. 가장 높은 신뢰도를 가진 레이블을 찾아보죠:

# %%
np.argmax(predictions[0])
# Out:
# 3

# %% [markdown]
# 모델은 이 이미지가 앵클 부츠(`class_name[9]`)라고 가장 확신하고 있습니다. 이 값이 맞는지 테스트 레이블을 확인해 보죠:

# %%
test_labels[0]
# Out:
# array([3], dtype=int32)

# %% [markdown]
# 10개 클래스에 대한 예측을 모두 그래프로 표현해 보겠습니다:

# %%
def plot_image(i, predictions_array, true_label, img):
    true_label, img = true_label[i][0], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                         100*np.max(predictions_array),
                                         class_names[true_label]),
               color=color)

def plot_value_array(i, predictions_array, true_label):
    true_label = true_label[i][0]
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %% [markdown]
# ### 예측 확인
#
# 훈련된 모델을 사용하여 일부 이미지에 대한 예측을 수행할 수 있습니다.

# %% [markdown]
# 0번째 원소의 이미지, 예측, 신뢰도 점수 배열을 확인해 보겠습니다.

# %%
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %%
i = 12
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %% [markdown]
# 몇 개의 이미지의 예측을 출력해 보죠. 올바르게 예측된 레이블은 파란색이고 잘못 예측된 레이블은 빨강색입니다. 숫자는 예측 레이블의 신뢰도 퍼센트(100점 만점)입니다. 신뢰도 점수가 높을 때도 잘못 예측할 수 있습니다.

# %%
# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i, predictions[i], test_labels, test_images)
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, predictions[i], test_labels)
plt.tight_layout()
plt.show()
