# %% [markdown]
# ![KakaoTalk_20230803_163633393.png](attachment:KakaoTalk_20230803_163633393.png)

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow.keras import datasets, layers, Model

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2024-02-12 23:52:33.005186: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-12 23:52:33.695568: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvrtc.so.11.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/juing/app/TensorRT-7.2.3.4/lib:/usr/lib/nvidia:/home/juing/.mujoco/mujoco210/bin:/usr/local/cuda-11.2/extras/CUPTI/lib64:/usr/local/cuda-11.2/lib64
# 2024-02-12 23:52:33.695691: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvrtc.so.11.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/juing/app/TensorRT-7.2.3.4/lib:/usr/lib/nvidia:/home/juing/.mujoco/mujoco210/bin:/usr/local/cuda-11.2/extras/CUPTI/lib64:/usr/local/cuda-11.2/lib64
# 2024-02-12 23:52:33.695699: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2.11.0

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
    # tf.config.set_logical_device_configuration(gpu, [tf.config.LogicalDeviceConfiguration(memory_limit=1024 * 3.5)])

# %%
# !pip install -U keras-cv==0.5.0
import keras_cv

# %%
print(keras_cv.__version__)
# Out:
# 0.5.0

# %%
import tensorflow_hub as hub

# %%
print(hub.__version__)
# Out:
# 0.13.0

# %% [markdown]
# ## CIFAR10 데이터셋 임포트하기

# %% [markdown]
# CIFAR10 데이터세트에는 10개 클래스에 60,000개의 컬러 이미지가 포함되어 있으며 각 클래스에는 6,000개의 이미지가 있습니다. 이 데이터세트는 50,000개의 훈련 이미지와 10,000개의 테스트 이미지로 나뉩니다. 클래스는 상호 배타적이며 서로 겹치지 않습니다.

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# ## 데이터 전처리
#
# 네트워크를 훈련하기 전에 데이터를 전처리해야 합니다. 훈련 세트에 있는 첫 번째 이미지를 보면 픽셀 값의 범위가 0~1 사이라는 것을 알 수 있습니다:

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# 신경망 모델에 주입하기 전에 이 값의 범위를 0~1 사이로 조정하겠습니다. 이렇게 하려면 255로 나누어야 합니다. *훈련 세트*와 *테스트 세트*를 동일한 방식으로 전처리하는 것이 중요합니다:

# %%
train_images = train_images.astype(np.float32)
train_images = train_images / 255.0

test_images = test_images.astype(np.float32)
test_images = test_images / 255.0

# %%
train_labels = train_labels.astype(np.int32)
test_labels = test_labels.astype(np.int32)

# %%
IMG_SIZE = 32 * 3

# %%
IMG_SIZE
# Out:
# 96

# %% [markdown]
# *훈련 세트*에서 처음 25개 이미지와 그 아래 클래스 이름을 출력해 보죠. 데이터 포맷이 올바른지 확인하고 네트워크 구성과 훈련할 준비를 마칩니다.

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %% [markdown]
# ## KerasCV
#
# https://keras.io/keras_cv/
#
# ### keras_cv.layers.RandAugmen
#
# RandAugment는 입력 이미지에 대해 Rand Augment 작업을 수행합니다.
#
# 이 레이어는 올인원 이미지 확대 레이어로 생각할 수 있습니다. 이 계층에서 구현된 정책은 광범위하게 벤치마킹되었으며 다양한 데이터 세트에 효과적입니다.

# %%
rand_augment = keras_cv.layers.RandAugment(value_range=(0, 1))
x_test = rand_augment(test_images[:25])
# Out:
# WARNING:tensorflow:From /home/juing/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /home/juing/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %%
plt.figure(figsize=(20, 10))
for i in range(25):
    
    plt.subplot(5, 10, i*2 + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(test_images[i])
    plt.xlabel("Orig: "+ class_names[test_labels[i][0]])
    
    plt.subplot(5, 10, i*2 + 2)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i])
    plt.xlabel("Aug: "+ class_names[test_labels[i][0]])
    
plt.show()

# %% [markdown]
# ## Datasets

# %%
BATCH_SIZE = 128

# %% [markdown]
# ### train datasets

# %%
def image_preprocess(image, label):
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, size=(IMG_SIZE, IMG_SIZE))
    
    label = tf.cast(label, tf.int32)
    return image, label

# %%
randaugment = keras_cv.layers.RandAugment(value_range=(0, 1))

def image_augmentation(image, label):
    image = randaugment(image)
    return image, label

# %%
datasets_train = tf.data.Dataset.from_tensor_slices((train_images, train_labels))

datasets_train = datasets_train.shuffle(buffer_size=len(train_labels))
datasets_train = datasets_train.batch(batch_size=BATCH_SIZE)

datasets_train = datasets_train.map(image_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
datasets_train = datasets_train.map(image_augmentation, num_parallel_calls=tf.data.AUTOTUNE)

datasets_train = datasets_train.prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
datasets_train
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 96, 96, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.int32, name=None))>

# %% [markdown]
# ### test datasets

# %%
datasets_test = tf.data.Dataset.from_tensor_slices((test_images, test_labels))

# %%
datasets_test = datasets_test.batch(batch_size=BATCH_SIZE)

datasets_test = datasets_test.map(image_preprocess, num_parallel_calls=tf.data.AUTOTUNE)

datasets_test = datasets_test.prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
datasets_test
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 96, 96, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.int32, name=None))>

# %% [markdown]
# ## https://keras.io/api/applications/

# %% [markdown]
# Keras 애플리케이션은 사전 훈련된 가중치와 함께 사용할 수 있는 딥 러닝 모델입니다. 이러한 모델은 예측, 특징 추출 및 미세 조정에 사용될 수 있습니다.
#
# 모델을 인스턴스화할 때 가중치가 자동으로 다운로드됩니다. 에 저장되어 있습니다 ~/.keras/models/.
#
# 인스턴스화 시 Keras 구성 파일에 설정된 이미지 데이터 형식에 따라 모델이 구축됩니다 ~/.keras/keras.json. 예를 들어, 을 설정한 경우 image_data_format=channels_last이 저장소에서 로드된 모든 모델은 "높이-너비-깊이" 데이터 형식 규칙에 따라 구축됩니다.

# %% [markdown]
# <table>
# <thead>
# <tr>
# <th>Model</th>
# <th style="text-align: right;">Size (MB)</th>
# <th style="text-align: right;">Top-1 Accuracy</th>
# <th style="text-align: right;">Top-5 Accuracy</th>
# <th style="text-align: right;">Parameters</th>
# <th style="text-align: right;">Depth</th>
# <th style="text-align: right;">Time (ms) per inference step (CPU)</th>
# <th style="text-align: right;">Time (ms) per inference step (GPU)</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><a href="xception">Xception</a></td>
# <td style="text-align: right;">88</td>
# <td style="text-align: right;">79.0%</td>
# <td style="text-align: right;">94.5%</td>
# <td style="text-align: right;">22.9M</td>
# <td style="text-align: right;">81</td>
# <td style="text-align: right;">109.4</td>
# <td style="text-align: right;">8.1</td>
# </tr>
# <tr>
# <td><a href="vgg/#vgg16-function">VGG16</a></td>
# <td style="text-align: right;">528</td>
# <td style="text-align: right;">71.3%</td>
# <td style="text-align: right;">90.1%</td>
# <td style="text-align: right;">138.4M</td>
# <td style="text-align: right;">16</td>
# <td style="text-align: right;">69.5</td>
# <td style="text-align: right;">4.2</td>
# </tr>
# <tr>
# <td><a href="vgg/#vgg19-function">VGG19</a></td>
# <td style="text-align: right;">549</td>
# <td style="text-align: right;">71.3%</td>
# <td style="text-align: right;">90.0%</td>
# <td style="text-align: right;">143.7M</td>
# <td style="text-align: right;">19</td>
# <td style="text-align: right;">84.8</td>
# <td style="text-align: right;">4.4</td>
# </tr>
# <tr>
# <td><a href="resnet/#resn
</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="convnext/#convnextbase-function">ConvNeXtBase</a></td>
# <td style="text-align: right;">338.58</td>
# <td style="text-align: right;">85.3%</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">88.5M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="convnext/#convnextlarge-function">ConvNeXtLarge</a></td>
# <td style="text-align: right;">755.07</td>
# <td style="text-align: right;">86.3%</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">197.7M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="convnext/#convnextxlarge-function">ConvNeXtXLarge</a></td>
# <td style="text-align: right;">1310</td>
# <td style="text-align: right;">86.7%</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">350.1M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ### 층 설정
#
# 신경망의 기본 빌딩 블록은 [*레이어*](https://www.tensorflow.org/api_docs/python/tf/keras/layers) 입니다. 레이어는 레이어에 공급된 데이터로부터 표현을 추출합니다. 이러한 표현은 당면한 문제에 의미가 있어야 합니다.
#
# 대부분 딥러닝은 간단한 층을 연결하여 구성됩니다. `tf.keras.layers.Dense`와 같은 층들의 가중치(parameter)는 훈련하는 동안 학습됩니다.

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/applications

# %%
input_shape = (IMG_SIZE, IMG_SIZE, 3)

# %%
input_shape
# Out:
# (96, 96, 3)

# %% [markdown]
# ### TensorFlow Hub

# %% [markdown]
# https://www.kaggle.com/models/google/mobilenet-v2

# %% [markdown]
# https://github.com/tensorflow/models/blob/master/research/slim/nets/mobilenet/README.md

# %%
model = tf.keras.Sequential([
    hub.KerasLayer("https://www.kaggle.com/models/google/mobilenet-v2/frameworks/TensorFlow2/variations/100-96-feature-vector/versions/2", trainable=True, input_shape=input_shape),
    layers.LayerNormalization(),
    tf.keras.layers.Dense(len(class_names), activation='softmax'),
])

# %%
model.summary(show_trainable=True)
# Out:
# Model: "sequential"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ============================================================================
#  keras_layer (KerasLayer)    (None, 1280)              2257984   Y
#
#  layer_normalization (LayerN  (None, 1280)             2560      Y
#  ormalization)
#
#  dense (Dense)               (None, 10)                12810     Y
#
# ============================================================================
# Total params: 2,273,354
# Trainable params: 2,239,242
# Non-trainable params: 34,112
# ____________________________________________________________________________

# %% [markdown]
# ### 모델 컴파일
#
# 모델을 훈련할 준비가 되기 전에 몇 가지 설정이 더 필요합니다. 다음은 모델의 [*컴파일*](https://www.tensorflow.org/api_docs/python/tf/keras/Model#compile) 단계에서 추가됩니다.
#
# - [*손실 함수*](https://www.tensorflow.org/api_docs/python/tf/keras/losses) - 훈련 중 모델이 얼마나 정확한지 측정합니다. 모델을 올바른 방향으로 "조정"하려면 이 함수를 최소화해야 합니다.
# - [*옵티마이저*](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers) - 모델이 인식하는 데이터와 해당 손실 함수를 기반으로 모델이 업데이트되는 방식입니다.
# - [*메트릭*](https://www.tensorflow.org/api_docs/python/tf/keras/metrics) — 훈련 및 테스트 단계를 모니터링하는 데 사용됩니다. 다음 예에서는 올바르게 분류된 이미지의 비율인 *정확도*를 사용합니다.

# %%
model.compile(optimizer=tf.optimizers.Adam(learning_rate=1e-03),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=[
                  tf.keras.metrics.SparseCategoricalAccuracy(),
              ])

# %%
model.summary(show_trainable=True)
# Out:
# Model: "sequential"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ============================================================================
#  keras_layer (KerasLayer)    (None, 1280)              2257984   Y
#
#  layer_normalization (LayerN  (None, 1280)             2560      Y
#  ormalization)
#
#  dense (Dense)               (None, 10)                12810     Y
#
# ============================================================================
# Total params: 2,273,354
# Trainable params: 2,239,242
# Non-trainable params: 34,112
# ____________________________________________________________________________

# %%
for idx, weight in enumerate(sorted(model.weights, key=lambda x: x.name)):
    print("{:<5d}: {}".format(idx, weight.name))
# Out:
# 0    : MobilenetV2/Conv/BatchNorm/beta:0
# 1    : MobilenetV2/Conv/BatchNorm/gamma:0
# 2    : MobilenetV2/Conv/BatchNorm/moving_mean:0
# 3    : MobilenetV2/Conv/BatchNorm/moving_variance:0
# 4    : MobilenetV2/Conv/weights:0
# 5    : MobilenetV2/Conv_1/BatchNorm/beta:0
# 6    : MobilenetV2/Conv_1/BatchNorm/gamma:0
# 7    : MobilenetV2/Conv_1/BatchNorm/moving_mean:0
# 8    : MobilenetV2/Conv_1/BatchNorm/moving_variance:0
# 9    : MobilenetV2/Conv_1/weights:0
# 10   : MobilenetV2/expanded_conv/depthwise/BatchNorm/beta:0
# 11   : MobilenetV2/expanded_conv/depthwise/BatchNorm/gamma:0
# 12   : MobilenetV2/expanded_conv/depthwise/BatchNorm/moving_mean:0
# 13   : MobilenetV2/expanded_conv/depthwise/BatchNorm/moving_variance:0
# 14   : MobilenetV2/expanded_conv/depthwise/depthwise_weights:0
# 15   : MobilenetV2/expanded_conv/project/BatchNorm/beta:0
# 16   : MobilenetV2/expanded_conv/project/BatchNorm/gamma:0
# 17   : MobilenetV2/expanded_conv/project/BatchNorm/moving_mean:0
# 18   : MobilenetV2/expanded_conv/project/BatchNorm/moving_variance:0
# 19   : MobilenetV2/expanded_conv/project/weights:0
# 20   : MobilenetV2/expanded_conv_1/depthwise/BatchNorm/beta:0
# 21   : MobilenetV2/expanded_conv_1/depthwise/BatchNorm/gamma:0
# 22   : MobilenetV2/expanded_conv_1/depthwise/BatchNorm/moving_mean:0
# 23   : MobilenetV2/expanded_conv_1/depthwise/BatchNorm/moving_variance:0
# 24   : MobilenetV2/expanded_conv_1/depthwise/depthwise_weights:0
# 25   : MobilenetV2/expanded_conv_1/expand/BatchNorm/beta:0
# 26   : MobilenetV2/expanded_conv_1/expand/BatchNorm/gamma:0
# 27   : MobilenetV2/expanded_conv_1/expand/BatchNorm/moving_mean:0
# 28   : MobilenetV2/expanded_conv_1/expand/BatchNorm/moving_variance:0
# 29   : MobilenetV2/expanded_conv_1/expand/weights:0
# 30   : MobilenetV2/expanded_conv_1/project/BatchNorm/beta:0
# 31   : MobilenetV2/expanded_conv_1/project/BatchNorm/gamma:0
# 32   : MobilenetV2/expanded_conv_1/project/BatchNorm/moving_mean:0
# 33   : MobilenetV2/expanded_conv_1/project/BatchNorm/moving_variance:0
# 34   : MobilenetV2/expanded_conv_1/project/weights:0
# 35   : MobilenetV2/expanded_conv_10/depthwise/BatchNorm/beta:0
# 36   : MobilenetV2/expanded_conv_10/depthwise/BatchNorm/gamma:0
# 37   : MobilenetV2/expanded_conv_10/depthwise/BatchNorm/moving_mean:0
# 38   : MobilenetV2/expanded_conv_10/depthwise/BatchNorm/moving_variance:0
# 39   : MobilenetV2/expanded_conv_10/depthwise/depthwise_weights:0
# 40   : MobilenetV2/expanded_conv_10/expand/BatchNorm/beta:0
# 41   : MobilenetV2/expanded_conv_10/expand/BatchNorm/gamma:0
# 42   : MobilenetV2/expanded_conv_10/expand/BatchNorm/moving
obilenetV2/expanded_conv_16/expand/BatchNorm/moving_mean:0
# 133  : MobilenetV2/expanded_conv_16/expand/BatchNorm/moving_variance:0
# 134  : MobilenetV2/expanded_conv_16/expand/weights:0
# 135  : MobilenetV2/expanded_conv_16/project/BatchNorm/beta:0
# 136  : MobilenetV2/expanded_conv_16/project/BatchNorm/gamma:0
# 137  : MobilenetV2/expanded_conv_16/project/BatchNorm/moving_mean:0
# 138  : MobilenetV2/expanded_conv_16/project/BatchNorm/moving_variance:0
# 139  : MobilenetV2/expanded_conv_16/project/weights:0
# 140  : MobilenetV2/expanded_conv_2/depthwise/BatchNorm/beta:0
# 141  : MobilenetV2/expanded_conv_2/depthwise/BatchNorm/gamma:0
# 142  : MobilenetV2/expanded_conv_2/depthwise/BatchNorm/moving_mean:0
# 143  : MobilenetV2/expanded_conv_2/depthwise/BatchNorm/moving_variance:0
# 144  : MobilenetV2/expanded_conv_2/depthwise/depthwise_weights:0
# 145  : MobilenetV2/expanded_conv_2/expand/BatchNorm/beta:0
# 146  : MobilenetV2/expanded_conv_2/expand/BatchNorm/gamma:0
# 147  : MobilenetV2/expanded_conv_2/expand/BatchNorm/moving_mean:0
# 148  : MobilenetV2/expanded_conv_2/expand/BatchNorm/moving_variance:0
# 149  : MobilenetV2/expanded_conv_2/expand/weights:0
# 150  : MobilenetV2/expanded_conv_2/project/BatchNorm/beta:0
# 151  : MobilenetV2/expanded_conv_2/project/BatchNorm/gamma:0
# 152  : MobilenetV2/expanded_conv_2/project/BatchNorm/moving_mean:0
# 153  : MobilenetV2/expanded_conv_2/project/BatchNorm/moving_variance:0
# 154  : MobilenetV2/expanded_conv_2/project/weights:0
# 155  : MobilenetV2/expanded_conv_3/depthwise/BatchNorm/beta:0
# 156  : MobilenetV2/expanded_conv_3/depthwise/BatchNorm/gamma:0
# 157  : MobilenetV2/expanded_conv_3/depthwise/BatchNorm/moving_mean:0
# 158  : MobilenetV2/expanded_conv_3/depthwise/BatchNorm/moving_variance:0
# 159  : MobilenetV2/expanded_conv_3/depthwise/depthwise_weights:0
# 160  : MobilenetV2/expanded_conv_3/expand/BatchNorm/beta:0
# 161  : MobilenetV2/expanded_conv_3/expand/BatchNorm/gamma:0
# 162  : MobilenetV2/expanded_conv_3/expand/BatchNorm/moving_mean:0
# 163  : MobilenetV2/expanded_conv_3/expand/BatchNorm/moving_variance:0
# 164  : MobilenetV2/expanded_conv_3/expand/weights:0
# 165  : MobilenetV2/expanded_conv_3/project/BatchNorm/beta:0
# 166  : MobilenetV2/expanded_conv_3/project/BatchNorm/gamma:0
# 167  : MobilenetV2/expanded_conv_3/project/BatchNorm/moving_mean:0
# 168  : MobilenetV2/expanded_conv_3/project/BatchNorm/moving_variance:0
# 169  : MobilenetV2/expanded_conv_3/project/weights:0
# 170  : MobilenetV2/expanded_conv_4/depthwise/BatchNorm/beta:0
# 171  : MobilenetV2/expanded_conv_4/depthwise/BatchNorm/gamma:0
# 172  : MobilenetV2/expanded_conv_4/depthwise/BatchNorm/moving_mean:0
# 173  : MobilenetV2/expanded_conv_4/depthwise/BatchNorm/moving_variance:0
# 174  : MobilenetV2/expanded_conv_4/depthwise/depthwise_weights:0
# 175  : MobilenetV2/expanded_conv_4/expand/BatchNorm/beta:0
# 176  : MobilenetV2/expanded_conv_4/expand/BatchNorm/gamma:0
# 177  : MobilenetV2/expanded_conv_4/expand/BatchNorm/moving_mean:0
# 178  : MobilenetV2/expanded_conv_4/expand/BatchNorm/moving_variance:0
# 179  : MobilenetV2/expanded_conv_4/expand/weights:0
# 180  : MobilenetV2/expanded_conv_4/project/BatchNorm/beta:0
obilenetV2/expanded_conv_7/expand/BatchNorm/moving_mean:0
# 223  : MobilenetV2/expanded_conv_7/expand/BatchNorm/moving_variance:0
# 224  : MobilenetV2/expanded_conv_7/expand/weights:0
# 225  : MobilenetV2/expanded_conv_7/project/BatchNorm/beta:0
# 226  : MobilenetV2/expanded_conv_7/project/BatchNorm/gamma:0
# 227  : MobilenetV2/expanded_conv_7/project/BatchNorm/moving_mean:0
# 228  : MobilenetV2/expanded_conv_7/project/BatchNorm/moving_variance:0
# 229  : MobilenetV2/expanded_conv_7/project/weights:0
# 230  : MobilenetV2/expanded_conv_8/depthwise/BatchNorm/beta:0
# 231  : MobilenetV2/expanded_conv_8/depthwise/BatchNorm/gamma:0
# 232  : MobilenetV2/expanded_conv_8/depthwise/BatchNorm/moving_mean:0
# 233  : MobilenetV2/expanded_conv_8/depthwise/BatchNorm/moving_variance:0
# 234  : MobilenetV2/expanded_conv_8/depthwise/depthwise_weights:0
# 235  : MobilenetV2/expanded_conv_8/expand/BatchNorm/beta:0
# 236  : MobilenetV2/expanded_conv_8/expand/BatchNorm/gamma:0
# 237  : MobilenetV2/expanded_conv_8/expand/BatchNorm/moving_mean:0
# 238  : MobilenetV2/expanded_conv_8/expand/BatchNorm/moving_variance:0
# 239  : MobilenetV2/expanded_conv_8/expand/weights:0
# 240  : MobilenetV2/expanded_conv_8/project/BatchNorm/beta:0
# 241  : MobilenetV2/expanded_conv_8/project/BatchNorm/gamma:0
# 242  : MobilenetV2/expanded_conv_8/project/BatchNorm/moving_mean:0
# 243  : MobilenetV2/expanded_conv_8/project/BatchNorm/moving_variance:0
# 244  : MobilenetV2/expanded_conv_8/project/weights:0
# 245  : MobilenetV2/expanded_conv_9/depthwise/BatchNorm/beta:0
# 246  : MobilenetV2/expanded_conv_9/depthwise/BatchNorm/gamma:0
# 247  : MobilenetV2/expanded_conv_9/depthwise/BatchNorm/moving_mean:0
# 248  : MobilenetV2/expanded_conv_9/depthwise/BatchNorm/moving_variance:0
# 249  : MobilenetV2/expanded_conv_9/depthwise/depthwise_weights:0
# 250  : MobilenetV2/expanded_conv_9/expand/BatchNorm/beta:0
# 251  : MobilenetV2/expanded_conv_9/expand/BatchNorm/gamma:0
# 252  : MobilenetV2/expanded_conv_9/expand/BatchNorm/moving_mean:0
# 253  : MobilenetV2/expanded_conv_9/expand/BatchNorm/moving_variance:0
# 254  : MobilenetV2/expanded_conv_9/expand/weights:0
# 255  : MobilenetV2/expanded_conv_9/project/BatchNorm/beta:0
# 256  : MobilenetV2/expanded_conv_9/project/BatchNorm/gamma:0
# 257  : MobilenetV2/expanded_conv_9/project/BatchNorm/moving_mean:0
# 258  : MobilenetV2/expanded_conv_9/project/BatchNorm/moving_variance:0
# 259  : MobilenetV2/expanded_conv_9/project/weights:0
# 260  : dense/bias:0
# 261  : dense/kernel:0
# 262  : layer_normalization/beta:0
# 263  : layer_normalization/gamma:0

# %% [markdown]
# ## 모델 훈련
#
# 신경망 모델을 훈련하려면 다음 단계가 필요합니다.
#
# 1. 훈련 데이터를 모델에 주입합니다-이 예에서는 `train_images`와 `train_labels` 배열입니다.
# 2. 모델이 이미지와 레이블을 매핑하는 방법을 배웁니다.
# 3. 테스트 세트에 대한 모델의 예측을 만듭니다-이 예에서는 `test_images` 배열입니다. 이 예측이 `test_labels` 배열의 레이블과 맞는지 확인합니다.
# 4. 예측이 `test_labels` 배열의 레이블과 일치하는지 확인합니다.

# %% [markdown]
# ### 모델 피드
#
# 훈련을 시작하려면 [`model.fit`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit) 메서드를 호출합니다. 모델을 훈련 데이터에 "맞추기(fit)" 때문에 이렇게 불립니다.

# %%
history  = model.fit(datasets_train, epochs=20, validation_data=datasets_test)
# Out:
# Epoch 1/20
# 391/391 [==============================] - 76s 136ms/step - loss: 1.2811 - sparse_categorical_accuracy: 0.6146 - val_loss: 0.8456 - val_sparse_categorical_accuracy: 0.7465
# Epoch 2/20
# 391/391 [==============================] - 53s 133ms/step - loss: 0.9321 - sparse_categorical_accuracy: 0.7091 - val_loss: 0.5062 - val_sparse_categorical_accuracy: 0.8597
# Epoch 3/20
# 391/391 [==============================] - 53s 134ms/step - loss: 0.8559 - sparse_categorical_accuracy: 0.7361 - val_loss: 0.5133 - val_sparse_categorical_accuracy: 0.8527
# Epoch 4/20
# 391/391 [==============================] - 53s 134ms/step - loss: 0.8082 - sparse_categorical_accuracy: 0.7528 - val_loss: 0.6049 - val_sparse_categorical_accuracy: 0.8345
# Epoch 5/20
# 391/391 [==============================] - 53s 134ms/step - loss: 0.7856 - sparse_categorical_accuracy: 0.7615 - val_loss: 0.5430 - val_sparse_categorical_accuracy: 0.8494
# Epoch 6/20
# 391/391 [==============================] - 53s 134ms/step - loss: 0.7547 - sparse_categorical_accuracy: 0.7739 - val_loss: 0.4833 - val_sparse_categorical_accuracy: 0.8718
# Epoch 7/20
# 391/391 [==============================] - 53s 134ms/step - loss: 0.7456 - sparse_categorical_accuracy: 0.7776 - val_loss: 0.6383 - val_sparse_categorical_accuracy: 0.8260
# Epoch 8/20
# 391/391 [==============================] - 53s 133ms/step - loss: 0.7348 - sparse_categorical_accuracy: 0.7823 - val_loss: 0.4626 - val_sparse_categorical_accuracy: 0.8819
# Epoch 9/20
# 391/391 [==============================] - 53s 134ms/step - loss: 0.7164 - sparse_categorical_accuracy: 0.7917 - val_loss: 0.4779 - val_sparse_categorical_accuracy: 0.8766
# Epoch 10/20
# 391/391 [==============================] - 53s 133ms/step - loss: 0.7104 - sparse_categorical_accuracy: 0.7928 - val_loss: 0.4837 - val_sparse_categorical_accuracy: 0.8729
# Epoch 11/20
# 391/391 [==============================] - 53s 133ms/step - loss: 0.7027 - sparse_categorical_accuracy: 0.7964 - val_loss: 0.4437 - val_sparse_categorical_accuracy: 0.8905
# Epoch 12/20
# 391/391 [==============================] - 53s 134ms/step - loss: 0.6951 - sparse_categorical_accuracy: 0.7988 - val_loss: 0.4494 - val_sparse_categorical_accuracy: 0.8879
# Epoch 13/20
# 391/391 [==============================] - 53s 134ms/step - loss: 0.6848 - sparse_categorical_accuracy: 0.8053 - val_loss: 0.4664 - val_sparse_categorical_accuracy: 0.8830
# Epoch 14/20
# 391/391 [==============================] - 53s 134ms/step - loss: 0.6720 - sparse_categorical_accuracy: 0.8099 - val_loss: 0.4603 - val_sparse_categorical_accuracy: 0.8902
# Epoch 15/20
# 391/391 [==============================] - 53s 134ms/step - loss: 0.6700 - sparse_categorical_accuracy: 0.8121 - val_loss: 0.4156 - val_sparse_categorical_accuracy: 0.9033
# Epoch 16/20
# 391/391 [==============================] - 53s 134ms/step - loss: 0.6618 - sparse_categorical_accuracy: 0.8150 - val_loss: 0.5137 - val_sparse_categorical_accuracy: 0.8705
# Epoch 17/20
# 391/391 [==============================] - 53s 134ms/step - loss: 0.6622 - sparse_categorical_accuracy: 0.8171 - val_loss: 0.5154 - val_sparse_categorical_accuracy: 0.8760
# Epoch 18/20
# 391/391 [==============================] - 53s 134ms/step - loss: 0.6485 - sparse_categorical_accuracy: 0.8230 - val_loss: 0.4330 - val_sparse_categorical_accuracy: 0.9017
# Epoch 19/20
# 391/391 [==============================] - 53s 134ms/step - loss: 0.6508 - sparse_categorical_accuracy: 0.8208 - val_loss: 0.4243 - val_sparse_categorical_accuracy: 0.9017
# Epoch 20/20
# 391/391 [==============================] - 53s 134ms/step - loss: 0.6436 - sparse_categorical_accuracy: 0.8259 - val_loss: 0.4829 - val_sparse_categorical_accuracy: 0.8917

# %%
plt.plot(history.history['sparse_categorical_accuracy'], label='accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %% [markdown]
# ## 미세 조정

# %% [markdown]
# ### 컨볼루션 베이스 모델 고정하기

# %%
model.layers[0].trainable = False

# %%
model.compile(optimizer=tf.optimizers.Adam(learning_rate=1e-03),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=[
                  tf.keras.metrics.SparseCategoricalAccuracy(),
              ])

# %%
model.summary(show_trainable=True)
# Out:
# Model: "sequential"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ============================================================================
#  keras_layer (KerasLayer)    (None, 1280)              2257984   N
#
#  layer_normalization (LayerN  (None, 1280)             2560      Y
#  ormalization)
#
#  dense (Dense)               (None, 10)                12810     Y
#
# ============================================================================
# Total params: 2,273,354
# Trainable params: 15,370
# Non-trainable params: 2,257,984
# ____________________________________________________________________________

# %%
history_fine  = model.fit(datasets_train, epochs=10, validation_data=datasets_test)
# Out:
# Epoch 1/10
# 391/391 [==============================] - 34s 78ms/step - loss: 0.5500 - sparse_categorical_accuracy: 0.8117 - val_loss: 0.2697 - val_sparse_categorical_accuracy: 0.9117
# Epoch 2/10
# 391/391 [==============================] - 31s 77ms/step - loss: 0.5355 - sparse_categorical_accuracy: 0.8154 - val_loss: 0.2712 - val_sparse_categorical_accuracy: 0.9140
# Epoch 3/10
# 391/391 [==============================] - 31s 77ms/step - loss: 0.5438 - sparse_categorical_accuracy: 0.8146 - val_loss: 0.2658 - val_sparse_categorical_accuracy: 0.9136
# Epoch 4/10
# 391/391 [==============================] - 31s 77ms/step - loss: 0.5349 - sparse_categorical_accuracy: 0.8172 - val_loss: 0.2693 - val_sparse_categorical_accuracy: 0.9138
# Epoch 5/10
# 391/391 [==============================] - 31s 78ms/step - loss: 0.5369 - sparse_categorical_accuracy: 0.8151 - val_loss: 0.2661 - val_sparse_categorical_accuracy: 0.9137
# Epoch 6/10
# 391/391 [==============================] - 31s 77ms/step - loss: 0.5358 - sparse_categorical_accuracy: 0.8156 - val_loss: 0.2657 - val_sparse_categorical_accuracy: 0.9144
# Epoch 7/10
# 391/391 [==============================] - 31s 77ms/step - loss: 0.5345 - sparse_categorical_accuracy: 0.8143 - val_loss: 0.2658 - val_sparse_categorical_accuracy: 0.9168
# Epoch 8/10
# 391/391 [==============================] - 31s 77ms/step - loss: 0.5267 - sparse_categorical_accuracy: 0.8189 - val_loss: 0.2666 - val_sparse_categorical_accuracy: 0.9146
# Epoch 9/10
# 391/391 [==============================] - 31s 77ms/step - loss: 0.5300 - sparse_categorical_accuracy: 0.8169 - val_loss: 0.2665 - val_sparse_categorical_accuracy: 0.9153
# Epoch 10/10
# 391/391 [==============================] - 31s 77ms/step - loss: 0.5318 - sparse_categorical_accuracy: 0.8171 - val_loss: 0.2627 - val_sparse_categorical_accuracy: 0.9144

# %%
plt.plot(history.history['sparse_categorical_accuracy'] + history_fine.history['sparse_categorical_accuracy'], label='accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'] + history_fine.history['val_sparse_categorical_accuracy'], label = 'val_accuracy')
plt.plot([19.5, 19.5], [0.5, 1], label='Start Fine Tuning')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %% [markdown]
# ---
