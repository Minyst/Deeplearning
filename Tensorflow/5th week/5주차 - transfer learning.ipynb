# %% [markdown]
# ![KakaoTalk_20230803_163633393.png](attachment:KakaoTalk_20230803_163633393.png)

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow.keras import datasets, layers, Model

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2024-02-13 00:18:53.864249: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-13 00:18:54.550673: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvrtc.so.11.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/juing/app/TensorRT-7.2.3.4/lib:/usr/lib/nvidia:/home/juing/.mujoco/mujoco210/bin:/usr/local/cuda-11.2/extras/CUPTI/lib64:/usr/local/cuda-11.2/lib64
# 2024-02-13 00:18:54.550800: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvrtc.so.11.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/juing/app/TensorRT-7.2.3.4/lib:/usr/lib/nvidia:/home/juing/.mujoco/mujoco210/bin:/usr/local/cuda-11.2/extras/CUPTI/lib64:/usr/local/cuda-11.2/lib64
# 2024-02-13 00:18:54.550808: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2.11.0

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
    # tf.config.set_logical_device_configuration(gpu, [tf.config.LogicalDeviceConfiguration(memory_limit=1024 * 3.5)])

# %%
# !pip install -U keras-cv==0.5.0
import keras_cv

# %%
print(keras_cv.__version__)
# Out:
# 0.5.0

# %% [markdown]
# ## CIFAR10 데이터셋 임포트하기

# %% [markdown]
# CIFAR10 데이터세트에는 10개 클래스에 60,000개의 컬러 이미지가 포함되어 있으며 각 클래스에는 6,000개의 이미지가 있습니다. 이 데이터세트는 50,000개의 훈련 이미지와 10,000개의 테스트 이미지로 나뉩니다. 클래스는 상호 배타적이며 서로 겹치지 않습니다.

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# ## 데이터 전처리
#
# 네트워크를 훈련하기 전에 데이터를 전처리해야 합니다. 훈련 세트에 있는 첫 번째 이미지를 보면 픽셀 값의 범위가 0~1 사이라는 것을 알 수 있습니다:

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# 신경망 모델에 주입하기 전에 이 값의 범위를 0~1 사이로 조정하겠습니다. 이렇게 하려면 255로 나누어야 합니다. *훈련 세트*와 *테스트 세트*를 동일한 방식으로 전처리하는 것이 중요합니다:

# %%
train_images = train_images.astype(np.float32)
train_images = train_images / 255.0

test_images = test_images.astype(np.float32)
test_images = test_images / 255.0

# %%
train_labels = train_labels.astype(np.int32)
test_labels = test_labels.astype(np.int32)

# %%
IMG_SIZE = 32 * 3

# %%
IMG_SIZE
# Out:
# 96

# %% [markdown]
# *훈련 세트*에서 처음 25개 이미지와 그 아래 클래스 이름을 출력해 보죠. 데이터 포맷이 올바른지 확인하고 네트워크 구성과 훈련할 준비를 마칩니다.

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %% [markdown]
# ## KerasCV
#
# https://keras.io/keras_cv/
#
# ### keras_cv.layers.RandAugmen
#
# RandAugment는 입력 이미지에 대해 Rand Augment 작업을 수행합니다.
#
# 이 레이어는 올인원 이미지 확대 레이어로 생각할 수 있습니다. 이 계층에서 구현된 정책은 광범위하게 벤치마킹되었으며 다양한 데이터 세트에 효과적입니다.

# %%
rand_augment = keras_cv.layers.RandAugment(value_range=(0, 1))
x_test = rand_augment(test_images[:25])
# Out:
# WARNING:tensorflow:From /home/juing/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /home/juing/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %%
plt.figure(figsize=(20, 10))
for i in range(25):
    
    plt.subplot(5, 10, i*2 + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(test_images[i])
    plt.xlabel("Orig: "+ class_names[test_labels[i][0]])
    
    plt.subplot(5, 10, i*2 + 2)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i])
    plt.xlabel("Aug: "+ class_names[test_labels[i][0]])
    
plt.show()

# %% [markdown]
# ## Datasets

# %%
BATCH_SIZE = 128

# %% [markdown]
# ### train datasets

# %%
def image_preprocess(image, label):
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, size=(IMG_SIZE, IMG_SIZE))
    
    label = tf.cast(label, tf.int32)
    return image, label

# %%
randaugment = keras_cv.layers.RandAugment(value_range=(0, 1))

# %%
def image_augmentation(image, label):
    image = randaugment(image)
    return image, label

# %%
datasets_train = tf.data.Dataset.from_tensor_slices((train_images, train_labels))

datasets_train = datasets_train.shuffle(buffer_size=len(train_labels))
datasets_train = datasets_train.batch(batch_size=BATCH_SIZE)

datasets_train = datasets_train.map(image_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
datasets_train = datasets_train.map(image_augmentation, num_parallel_calls=tf.data.AUTOTUNE)

datasets_train = datasets_train.prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
datasets_train
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 96, 96, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.int32, name=None))>

# %% [markdown]
# ### test datasets

# %%
datasets_test = tf.data.Dataset.from_tensor_slices((test_images, test_labels))

# %%
datasets_test = datasets_test.batch(batch_size=BATCH_SIZE)

datasets_test = datasets_test.map(image_preprocess, num_parallel_calls=tf.data.AUTOTUNE)

datasets_test = datasets_test.prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
datasets_test
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 96, 96, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.int32, name=None))>

# %% [markdown]
# ## https://keras.io/api/applications/

# %% [markdown]
# Keras 애플리케이션은 사전 훈련된 가중치와 함께 사용할 수 있는 딥 러닝 모델입니다. 이러한 모델은 예측, 특징 추출 및 미세 조정에 사용될 수 있습니다.
#
# 모델을 인스턴스화할 때 가중치가 자동으로 다운로드됩니다. 에 저장되어 있습니다 ~/.keras/models/.
#
# 인스턴스화 시 Keras 구성 파일에 설정된 이미지 데이터 형식에 따라 모델이 구축됩니다 ~/.keras/keras.json. 예를 들어, 을 설정한 경우 image_data_format=channels_last이 저장소에서 로드된 모든 모델은 "높이-너비-깊이" 데이터 형식 규칙에 따라 구축됩니다.

# %% [markdown]
# <table>
# <thead>
# <tr>
# <th>Model</th>
# <th style="text-align: right;">Size (MB)</th>
# <th style="text-align: right;">Top-1 Accuracy</th>
# <th style="text-align: right;">Top-5 Accuracy</th>
# <th style="text-align: right;">Parameters</th>
# <th style="text-align: right;">Depth</th>
# <th style="text-align: right;">Time (ms) per inference step (CPU)</th>
# <th style="text-align: right;">Time (ms) per inference step (GPU)</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><a href="xception">Xception</a></td>
# <td style="text-align: right;">88</td>
# <td style="text-align: right;">79.0%</td>
# <td style="text-align: right;">94.5%</td>
# <td style="text-align: right;">22.9M</td>
# <td style="text-align: right;">81</td>
# <td style="text-align: right;">109.4</td>
# <td style="text-align: right;">8.1</td>
# </tr>
# <tr>
# <td><a href="vgg/#vgg16-function">VGG16</a></td>
# <td style="text-align: right;">528</td>
# <td style="text-align: right;">71.3%</td>
# <td style="text-align: right;">90.1%</td>
# <td style="text-align: right;">138.4M</td>
# <td style="text-align: right;">16</td>
# <td style="text-align: right;">69.5</td>
# <td style="text-align: right;">4.2</td>
# </tr>
# <tr>
# <td><a href="vgg/#vgg19-function">VGG19</a></td>
# <td style="text-align: right;">549</td>
# <td style="text-align: right;">71.3%</td>
# <td style="text-align: right;">90.0%</td>
# <td style="text-align: right;">143.7M</td>
# <td style="text-align: right;">19</td>
# <td style="text-align: right;">84.8</td>
# <td style="text-align: right;">4.4</td>
# </tr>
# <tr>
# <td><a href="resnet/#resnet50-function">ResNet50</a></td>
# <td style="text-align: right;">98</td>
# <td style="text-align: right;">74.9%</td>
# <td style="text-align: right;">92.1%</td>
# <td style="text-align: right;">25.6M</td>
# <td style="text-align: right;">107</td>
# <td style="text-align: right;">58.2</td>
# <td style="text-align: right;">4.6</td>
# </tr>
# <tr>
# <td><a href="resnet/#resnet50v2-function">ResNet50V2</a></td>
# <td style="text-align: right;">98</td>
# <td style="text-align: right;">76.0%</td>
# <td style="text-align: right;">93.0%</td>
# <td style="text-align: right;">25.6M</td>
# <td style="text-align: right;">103</td>
# <td style="text-align: right;">45.6</td>
# <td style="text-align: right;">4.4</td>
# </tr>
# <tr>
# <td><a href="resnet/#resnet101-function">ResNet101</a></td>
# <td style="text-align: right;">171</td>
# <td style="text-align: right;">76.4%</td>
# <td style="text-align: right;">92.8%</td>
# <td style="text-align: right;">44.7M</td>
# <td style="text-align: right;">209</td>
# <td style="text-align: right;">89.6</td>
# <td style="text-align: right;">5.2</td>
# </tr>
# <tr>
# <td><a href="resnet/#resnet101v2-function">ResNet101V2</a></td>
# <td style="text-align: right;">171</td>
# <td style="text-align: right;">77.2%</td>
# <td style="text-align: right;">93.8%</td>
# <td style="text-align: right;">44.7M</td>
# <td style="text-align: right;">205</td>
# <td style="text-align: right;">72.7</td>
# <td style="text-align: right;">5.4</td>
# </tr>
# <tr>
# <td><a href="resnet/#resnet152-function">ResNet152</a></td>
# <td style="text-align: right;">232</td>
# <td style="text-align: right;">76.6%</td>
# <td style="text-align: right;">93.1%</td>
# <td style="text-align: right;">60.4M</td>
# <td style="text-align: right;">311</td>
# <td style="text-align: right;">127.4</td>
# <td style="text-align: right;">6.5</td>
# </tr>
# <tr>
# <td><a href="resnet/#resnet152v2-function">ResNet152V2</a></td>
# <td style="text-align: right;">232</td>
# <td style="text-align: right;">78.0%</td>
# <td style="text-align: right;">94.2%</td>
# <td style="text-align: right;">60.4M</td>
# <td style="text-align: right;">307</td>
# <td style="text-align: right;">107.5</td>
# <td style="text-align: right;">6.6</td>
# </tr>
# <tr>
# <td><a href="inceptionv3">InceptionV3</a></td>
# <td style="text-align: right;">92</td>
# <td style="text-align: right;">77.9%</td>
# <td style="text-align: right;">93.7%</td>
# <td style="text-align: right;">23.9M</td>
# <td style="text-align: right;">189</td>
# <td style="text-align: right;">42.2</td>
# <td style="text-align: right;">6.9</td>
# </tr>
# <tr>
# <td><a href="inceptionresnetv2">InceptionResNetV2</a></td>
# <td style="text-align: right;">215</td>
# <td style="text-align: right;">80.3%</td>
# <td style="text-align: right;">95.3%</td>
# <td style="text-align: right;">55.9M</td>
# <td style="text-align: right;">449</td>
# <td style="text-align: right;">130.2</td>
# <td style="text-align: right;">10.0</td>
# </tr>
# <tr>
# <td><a href="mobilenet">MobileNet</a></td>
# <td style="text-align: right;">16</td>
# <td style="text-align: right;">70.4%</td>
# <td style="text-align: right;">89.5%</td>
# <td style="text-align: right;">4.3M</td>
# <td style="text-align: right;">55</td>
# <td style="text-align: right;">22.6</td>
# <td style="text-align: right;">3.4</td>
# </tr>
# <tr>
# <td><a href="mobilenet/#mobilenetv2-function">MobileNetV2</a></td>
# <td style="text-align: right;">14</td>
# <td style="text-align: right;">71.3%</td>
# <td style="text-align: right;">90.1%</td>
# <td style="text-align: right;">3.5M</td>
# <td style="text-align: right;">105</td>
# <td style="text-align: right;">25.9</td>
# <td style="text-align: right;">3.8</td>
# </tr>
# <tr>
# <td><a href="densenet/#densenet121-function">DenseNet121</a></td>
# <td style="text-align: right;">33</td>
# <td style="text-align: right;">75.0%</td>
# <td style="text-align: right;">92.3%</td>
# <td style="text-align: right;">8.1M</td>
# <td style="text-align: right;">242</td>
# <td style="text-align: right;">77.1</td>
# <td style="text-align: right;">5.4</td>
# </tr>
# <tr>
# <td><a href="densenet/#densenet169-function">DenseNet169</a></td>
# <td style="text-align: right;">57</td>
# <td style="text-align: right;">76.2%</td>
# <td style="text-align: right;">93.2%</td>
# <td style="text-align: right;">14.3M</td>
# <td style="text-align: right;">338</td>
# <td style="text-align: right;">96.4</td>
# <td style="text-align: right;">6.3</td>
# </tr>
# <tr>
# <td><a href="densenet/#densenet201-function">DenseNet201</a></td>
# <td style="text-align: right;">80</td>
# <td style="text-align: right;">77.3%</td>
# <td style="text-align: right;">93.6%</td>
# <td style="text-align: right;">20.2M</td>
# <td style="text-align: right;">402</td>
# <td style="text-align: right;">127.2</td>
# <td style="text-align: right;">6.7</td>
# </tr>
# <tr>
# <td><a href="nasnet/#nasnetmobile-function">NASNetMobile</a></td>
# <td style="text-align: right;">23</td>
# <td style="text-align: right;">74.4%</td>
# <td style="text-align: right;">91.9%</td>
# <td style="text-align: right;">5.3M</td>
# <td style="text-align: right;">389</td>
# <td style="text-align: right;">27.0</td>
# <td style="text-align: right;">6.7</td>
# </tr>
# <tr>
# <td><a href="nasnet/#nasnetlarge-function">NASNetLarge</a></td>
# <td style="text-align: right;">343</td>
# <td style="text-align: right;">82.5%</td>
# <td style="text-align: right;">96.0%</td>
# <td style="text-align: right;">88.9M</td>
# <td style="text-align: right;">533</td>
# <td style="text-align: right;">344.5</td>
# <td style="text-align: right;">20.0</td>
# </tr>
# <tr>
# <td><a href="efficientnet/#efficientnetb0-function">EfficientNetB0</a></td>
# <td style="text-align: right;">29</td>
# <td style="text-align: right;">77.1%</td>
# <td style="text-align: right;">93.3%</td>
# <td style="text-align: right;">5.3M</td>
# <td style="text-align: right;">132</td>
# <td style="text-align: right;">46.0</td>
# <td style="text-align: right;">4.9</td>
# </tr>
# <tr>
# <td><a href="efficientnet/#efficientnetb1-function">EfficientNetB1</a></td>
# <td style="text-align: right;">31</td>
# <td style="text-align: right;">79.1%</td>
# <td style="text-align: right;">94.4%</td>
# <td style="text-align: right;">7.9M</td>
# <td style="text-align: right;">186</td>
# <td style="text-align: right;">60.2</td>
# <td style="text-align: right;">5.6</td>
# </tr>
# <tr>
# <td><a href="efficientnet/#efficientnetb2-function">EfficientNetB2</a></td>
# <td style="text-align: right;">36</td>
# <td style="text-align: right;">80.1%</td>
# <td style="text-align: right;">94.9%</td>
# <td style="text-align: right;">9.2M</td>
# <td style="text-align: right;">186</td>
# <td style="text-align: right;">80.8</td>
# <td style="text-align: right;">6.5</td>
# </tr>
# <tr>
# <td><a href="efficientnet/#efficientnetb3-function">EfficientNetB3</a></td>
# <td style="text-align: right;">48</td>
# <td style="text-align: right;">81.6%</td>
# <td style="text-align: right;">95.7%</td>
# <td style="text-align: right;">12.3M</td>
# <td style="text-align: right;">210</td>
# <td style="text-align: right;">140.0</td>
# <td style="text-align: right;">8.8</td>
# </tr>
# <tr>
# <td><a href="efficientnet/#efficientnetb4-function">EfficientNetB4</a></td>
# <td style="text-align: right;">75</td>
# <td style="text-align: right;">82.9%</td>
# <td style="text-align: right;">96.4%</td>
# <td style="text-align: right;">19.5M</td>
# <td style="text-align: right;">258</td>
# <td style="text-align: right;">308.3</td>
# <td style="text-align: right;">15.1</td>
# </tr>
# <tr>
# <td><a href="efficientnet/#efficientnetb5-function">EfficientNetB5</a></td>
# <td style="text-align: right;">118</td>
# <td style="text-align: right;">83.6%</td>
# <td style="text-align: right;">96.7%</td>
# <td style="text-align: right;">30.6M</td>
# <td style="text-align: right;">312</td>
# <td style="text-align: right;">579.2</td>
# <td style="text-align: right;">25.3</td>
# </tr>
# <tr>
# <td><a href="efficientnet/#efficientnetb6-function">EfficientNetB6</a></td>
# <td style="text-align: right;">166</td>
# <td style="text-align: right;">84.0%</td>
# <td style="text-align: right;">96.8%</td>
# <td style="text-align: right;">43.3M</td>
# <td style="text-align: right;">360</td>
# <td style="text-align: right;">958.1</td>
# <td style="text-align: right;">40.4</td>
# </tr>
# <tr>
# <td><a href="efficientnet/#efficientnetb7-function">EfficientNetB7</a></td>
# <td style="text-align: right;">256</td>
# <td style="text-align: right;">84.3%</td>
# <td style="text-align: right;">97.0%</td>
# <td style="text-align: right;">66.7M</td>
# <td style="text-align: right;">438</td>
# <td style="text-align: right;">1578.9</td>
# <td style="text-align: right;">61.6</td>
# </tr>
# <tr>
# <td><a href="efficientnet_v2/#efficientnetv2b0-function">EfficientNetV2B0</a></td>
# <td style="text-align: right;">29</td>
# <td style="text-align: right;">78.7%</td>
# <td style="text-align: right;">94.3%</td>
# <td style="text-align: right;">7.2M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="efficientnet_v2/#efficientnetv2b1-function">EfficientNetV2B1</a></td>
# <td style="text-align: right;">34</td>
# <td style="text-align: right;">79.8%</td>
# <td style="text-align: right;">95.0%</td>
# <td style="text-align: right;">8.2M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="efficientnet_v2/#efficientnetv2b2-function">EfficientNetV2B2</a></td>
# <td style="text-align: right;">42</td>
# <td style="text-align: right;">80.5%</td>
# <td style="text-align: right;">95.1%</td>
# <td style="text-align: right;">10.2M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="efficientnet_v2/#efficientnetv2b3-function">EfficientNetV2B3</a></td>
# <td style="text-align: right;">59</td>
# <td style="text-align: right;">82.0%</td>
# <td style="text-align: right;">95.8%</td>
# <td style="text-align: right;">14.5M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="efficientnet_v2/#efficientnetv2s-function">EfficientNetV2S</a></td>
# <td style="text-align: right;">88</td>
# <td style="text-align: right;">83.9%</td>
# <td style="text-align: right;">96.7%</td>
# <td style="text-align: right;">21.6M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="efficientnet_v2/#efficientnetv2m-function">EfficientNetV2M</a></td>
# <td style="text-align: right;">220</td>
# <td style="text-align: right;">85.3%</td>
# <td style="text-align: right;">97.4%</td>
# <td style="text-align: right;">54.4M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="efficientnet_v2/#efficientnetv2l-function">EfficientNetV2L</a></td>
# <td style="text-align: right;">479</td>
# <td style="text-align: right;">85.7%</td>
# <td style="text-align: right;">97.5%</td>
# <td style="text-align: right;">119.0M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="convnext/#convnexttiny-function">ConvNeXtTiny</a></td>
# <td style="text-align: right;">109.42</td>
# <td style="text-align: right;">81.3%</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">28.6M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="convnext/#convnextsmall-function">ConvNeXtSmall</a></td>
# <td style="text-align: right;">192.29</td>
# <td style="text-align: right;">82.3%</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">50.2M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="convnext/#convnextbase-function">ConvNeXtBase</a></td>
# <td style="text-align: right;">338.58</td>
# <td style="text-align: right;">85.3%</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">88.5M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="convnext/#convnextlarge-function">ConvNeXtLarge</a></td>
# <td style="text-align: right;">755.07</td>
# <td style="text-align: right;">86.3%</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">197.7M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# <tr>
# <td><a href="convnext/#convnextxlarge-function">ConvNeXtXLarge</a></td>
# <td style="text-align: right;">1310</td>
# <td style="text-align: right;">86.7%</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">350.1M</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# <td style="text-align: right;">-</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ### 층 설정
#
# 신경망의 기본 빌딩 블록은 [*레이어*](https://www.tensorflow.org/api_docs/python/tf/keras/layers) 입니다. 레이어는 레이어에 공급된 데이터로부터 표현을 추출합니다. 이러한 표현은 당면한 문제에 의미가 있어야 합니다.
#
# 대부분 딥러닝은 간단한 층을 연결하여 구성됩니다. `tf.keras.layers.Dense`와 같은 층들의 가중치(parameter)는 훈련하는 동안 학습됩니다.

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/applications

# %%
input_shape = (IMG_SIZE, IMG_SIZE, 3)

# %%
input_shape
# Out:
# (96, 96, 3)

# %% [markdown]
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
! rm -rf ~/.keras/models/*

# %%
MobileNetV2 = tf.keras.applications.MobileNetV2(
    input_shape=input_shape,
    include_top=False,
    weights='imagenet'
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_96_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %%
inputs = MobileNetV2.input

x = MobileNetV2.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.LayerNormalization()(x)

outputs = layers.Dense(len(class_names), activation='softmax')(x)

# %%
model = Model(inputs=inputs, outputs=outputs)

# %%
model.summary(show_trainable=True)
# Out:
# Model: "model"
# _____________________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to                     Trainable
# =============================================================================================================
#  input_1 (InputLayer)           [(None, 96, 96, 3)]  0           []                               Y
#
#  Conv1 (Conv2D)                 (None, 48, 48, 32)   864         ['input_1[0][0]']                Y
#
#  bn_Conv1 (BatchNormalization)  (None, 48, 48, 32)   128         ['Conv1[0][0]']                  Y
#
#  Conv1_relu (ReLU)              (None, 48, 48, 32)   0           ['bn_Conv1[0][0]']               Y
#
#  expanded_conv_depthwise (Depth  (None, 48, 48, 32)  288         ['Conv1_relu[0][0]']             Y
#  wiseConv2D)
#
#  expanded_conv_depthwise_BN (Ba  (None, 48, 48, 32)  128         ['expanded_conv_depthwise[0][0]  Y
#  tchNormalization)                                               ']
#
#  expanded_conv_depthwise_relu (  (None, 48, 48, 32)  0           ['expanded_conv_depthwise_BN[0]  Y
#  ReLU)                                                           [0]']
#
#  expanded_conv_project (Conv2D)  (None, 48, 48, 16)  512         ['expanded_conv_depthwise_relu[  Y
#                                                                  0][0]']
#
#  expanded_conv_project_BN (Batc  (None, 48, 48, 16)  64          ['expanded_conv_project[0][0]']  Y
#  hNormalization)
#
#  block_1_expand (Conv2D)        (None, 48, 48, 96)   1536        ['expanded_conv_project_BN[0][0  Y
#                                                                  ]']
#
#  block_1_expand_BN (BatchNormal  (None, 48, 48, 96)  384         ['block_1_expand[0][0]']         Y
#  ization)
#
#  block_1_expand_relu (ReLU)     (None, 48, 48, 96)   0           ['block_1_expand_BN[0][0]']      Y
#
#  block_1_pad (ZeroPadding2D)    (None, 49, 49, 96)   0           ['block_1_expand_relu[0][0]']    Y
#
#  block_1_depthwise (DepthwiseCo  (None, 24, 24, 96)  864         ['block_1_pad[0][0]']            Y
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 24, 24, 96)  384         ['block_1_depthwise[0][0]']      Y
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 24, 24, 96)   0           ['block_1_depthwise_BN[0][0]']   Y
#
#  block_1_project (Conv2D)       (None, 24, 24, 24)   2304        ['block_1_depthwise_relu[0][0]'  Y
#                                                                  ]
#
#  block_1_project_BN (BatchNorma  (None, 24, 24, 24)  96          ['block_1_project[0][0]']        Y
#  lization)
#
#  block_2_expand (Conv2D)        (None, 24, 24, 144)  3456        ['block_1_project_BN[0][0]']     Y
#
#  block_2_expand_BN (BatchNormal  (None, 24, 24, 144)  576        ['block_2_expand[0][0]']         Y
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 24, 24, 144)  0           ['block_2_expand_BN[0][0]']      Y
#
#  block_2_depthwise (DepthwiseCo  (None, 24, 24, 144)  1296       ['block_2_expand_relu[0][0]']    Y
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 24, 24, 144)  576        ['block_2_depthwise[0][0]']      Y
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 24, 24, 144)  0           ['block_2_depthwise_BN[0][0]']   Y
#
#  block_2_project (Conv2D)       (None, 24, 24, 24)   3456        ['block_2_depthwise_relu[0][0]'  Y
#                                                                  ]
#
#  block_2_project_BN (BatchNorma  (None, 24, 24, 24)  96          ['block_2_project[0][0]']        Y
#  lization)
#
#  block_2_add (Add)              (None, 24, 24, 24)   0           ['block_1_project_BN[0][0]',     Y
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 24, 24, 144)  3456        ['block_2_add[0][0]']            Y
#
#  block_3_expand_BN (BatchNormal  (None, 24, 24, 144)  576        ['block_3_expand[0][0]']         Y
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 24, 24, 144)  0           ['block_3_expand_BN[0][0]']      Y
#
#  block_3_pad (ZeroPadding2D)    (None, 25, 25, 144)  0           ['block_3_expand_relu[0][0]']    Y
#
#  block_3_depthwise (DepthwiseCo  (None, 12, 12, 144)  1296       ['block_3_pad[0][0]']            Y
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 12, 12, 144)  576        ['block_3_depthwise[0][0]']      Y
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 12, 12, 144)  0           ['block_3_depthwise_BN[0][0]']   Y
#
#  block_3_project (Conv2D)       (None, 12, 12, 32)   4608        ['block_3_depthwise_relu[0][0]'  Y
#                                                                  ]
#
#  block_3_project_BN (BatchNorma  (None, 12, 12, 32)  128         ['block_3_project[0][0]']        Y
#  lization)
#
#  block_4_expand (Conv2D)        (None, 12, 12, 192)  6144        ['block_3_project_BN[0][0]']     Y
#
#  block_4_expand_BN (BatchNormal  (None, 12, 12, 192)  768        ['block_4_expand[0][0]']         Y
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 12, 12, 192)  0           ['block_4_expand_BN[0][0]']      Y
#
#  block_4_depthwise (DepthwiseCo  (None, 12, 12, 192)  1728       ['block_4_expand_relu[0][0]']    Y
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 12, 12, 192)  768        ['block_4_depthwise[0][0]']      Y
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 12, 12, 192)  0           ['block_4_depthwise_BN[0][0]']   Y
#
#  block_4_project (Conv2D)       (None, 12, 12, 32)   6144        ['block_4_depthwise_relu[0][0]'  Y
#                                                                  ]
#
#  block_4_project_BN (BatchNorma  (None, 12, 12, 32)  128         ['block_4_project[0][0]']        Y
#  lization)
#
#  block_4_add (Add)              (None, 12, 12, 32)   0           ['block_3_project_BN[0][0]',     Y
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 12, 12, 192)  6144        ['block_4_add[0][0]']            Y
#
#  block_5_expand_BN (BatchNormal  (None, 12, 12, 192)  768        ['block_5_expand[0][0]']         Y
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 12, 12, 192)  0           ['block_5_expand_BN[0][0]']      Y
#
#  block_5_depthwise (DepthwiseCo  (None, 12, 12, 192)  1728       ['block_5_expand_relu[0][0]']    Y
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 12, 12, 192)  768        ['block_5_depthwise[0][0]']      Y
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 12, 12, 192)  0           ['block_5_depthwise_BN[0][0]']   Y
#
#  block_5_project (Conv2D)       (None, 12, 12, 32)   6144        ['block_5_depthwise_relu[0][0]'  Y
#                                                                  ]
#
#  block_5_project_BN (BatchNorma  (None, 12, 12, 32)  128         ['block_5_project[0][0]']        Y
#  lization)
#
#  block_5_add (Add)              (None, 12, 12, 32)   0           ['block_4_add[0][0]',            Y
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 12, 12, 192)  6144        ['block_5_add[0][0]']            Y
#
#  block_6_expand_BN (BatchNormal  (None, 12, 12, 192)  768        ['block_6_expand[0][0]']         Y
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 12, 12, 192)  0           ['block_6_expand_BN[0][0]']      Y
#
#  block_6_pad (ZeroPadding2D)    (None, 13, 13, 192)  0           ['block_6_expand_relu[0][0]']    Y
#
#  block_6_depthwise (DepthwiseCo  (None, 6, 6, 192)   1728        ['block_6_pad[0][0]']            Y
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 6, 6, 192)   768         ['block_6_depthwise[0][0]']      Y
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 6, 6, 192)    0           ['block_6_depthwise_BN[0][0]']   Y
#
#  block_6_project (Conv2D)       (None, 6, 6, 64)     12288       ['block_6_depthwise_relu[0][0]'  Y
#                                                                  ]
#
#  block_6_project_BN (BatchNorma  (None, 6, 6, 64)    256         ['block_6_project[0][0]']        Y
#  lization)
#
#  block_7_expand (Conv2D)        (None, 6, 6, 384)    24576       ['block_6_project_BN[0][0]']     Y
#
#  block_7_expand_BN (BatchNormal  (None, 6, 6, 384)   1536        ['block_7_expand[0][0]']         Y
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 6, 6, 384)    0           ['block_7_expand_BN[0][0]']      Y
#
#  block_7_depthwise (DepthwiseCo  (None, 6, 6, 384)   3456        ['block_7_expand_relu[0][0]']    Y
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 6, 6, 384)   1536        ['block_7_depthwise[0][0]']      Y
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 6, 6, 384)    0           ['block_7_depthwise_BN[0][0]']   Y
#
#  block_7_project (Conv2D)       (None, 6, 6, 64)     24576       ['block_7_depthwise_relu[0][0]'  Y
#                                                                  ]
#
#  block_7_project_BN (BatchNorma  (None, 6, 6, 64)    256         ['block_7_project[0][0]']        Y
#  lization)
#
#  block_7_add (Add)              (None, 6, 6, 64)     0           ['block_6_project_BN[0][0]',     Y
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 6, 6, 384)    24576       ['block_7_add[0][0]']            Y
#
#  block_8_expand_BN (BatchNormal  (None, 6, 6, 384)   1536        ['block_8_expand[0][0]']         Y
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 6, 6, 384)    0           ['block_8_expand_BN[0][0]']      Y
#
#  block_8_depthwise (DepthwiseCo  (None, 6, 6, 384)   3456        ['block_8_expand_relu[0][0]']    Y
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 6, 6, 384)   1536        ['block_8_depthwise[0][0]']      Y
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 6, 6, 384)    0           ['block_8_depthwise_BN[0][0]']   Y
#
#  block_8_project (Conv2D)       (None, 6, 6, 64)     24576       ['block_8_depthwise_relu[0][0]'  Y
#                                                                  ]
#
#  block_8_project_BN (BatchNorma  (None, 6, 6, 64)    256         ['block_8_project[0][0]']        Y
#  lization)
#
#  block_8_add (Add)              (None, 6, 6, 64)     0           ['block_7_add[0][0]',            Y
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 6, 6, 384)    24576       ['block_8_add[0][0]']            Y
#
#  block_9_expand_BN (BatchNormal  (None, 6, 6, 384)   1536        ['block_9_expand[0][0]']         Y
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 6, 6, 384)    0           ['block_9_expand_BN[0][0]']      Y
#
#  block_9_depthwise (DepthwiseCo  (None, 6, 6, 384)   3456        ['block_9_expand_relu[0][0]']    Y
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 6, 6, 384)   1536        ['block_9_depthwise[0][0]']      Y
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 6, 6, 384)    0           ['block_9_depthwise_BN[0][0]']   Y
#
#  block_9_project (Conv2D)       (None, 6, 6, 64)     24576       ['block_9_depthwise_relu[0][0]'  Y
#                                                                  ]
#
#  block_9_project_BN (BatchNorma  (None, 6, 6, 64)    256         ['block_9_project[0][0]']        Y
#  lization)
#
#  block_9_add (Add)              (None, 6, 6, 64)     0           ['block_8_add[0][0]',            Y
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 6, 6, 384)    24576       ['block_9_add[0][0]']            Y
#
#  block_10_expand_BN (BatchNorma  (None, 6, 6, 384)   1536        ['block_10_expand[0][0]']        Y
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 6, 6, 384)    0           ['block_10_expand_BN[0][0]']     Y
#
#  block_10_depthwise (DepthwiseC  (None, 6, 6, 384)   3456        ['block_10_expand_relu[0][0]']   Y
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 6, 6, 384)   1536        ['block_10_depthwise[0][0]']     Y
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 6, 6, 384)   0           ['block_10_depthwise_BN[0][0]']  Y
#
#  block_10_project (Conv2D)      (None, 6, 6, 96)     36864       ['block_10_depthwise_relu[0][0]  Y
#                                                                  ']
#
#  block_10_project_BN (BatchNorm  (None, 6, 6, 96)    384         ['block_10_project[0][0]']       Y
#  alization)
#
#  block_11_expand (Conv2D)       (None, 6, 6, 576)    55296       ['block_10_project_BN[0][0]']    Y
#
#  block_11_expand_BN (BatchNorma  (None, 6, 6, 576)   2304        ['block_11_expand[0][0]']        Y
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 6, 6, 576)    0           ['block_11_expand_BN[0][0]']     Y
#
#  block_11_depthwise (DepthwiseC  (None, 6, 6, 576)   5184        ['block_11_expand_relu[0][0]']   Y
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 6, 6, 576)   2304        ['block_11_depthwise[0][0]']     Y
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 6, 6, 576)   0           ['block_11_depthwise_BN[0][0]']  Y
#
#  block_11_project (Conv2D)      (None, 6, 6, 96)     55296       ['block_11_depthwise_relu[0][0]  Y
#                                                                  ']
#
#  block_11_project_BN (BatchNorm  (None, 6, 6, 96)    384         ['block_11_project[0][0]']       Y
#  alization)
#
#  block_11_add (Add)             (None, 6, 6, 96)     0           ['block_10_project_BN[0][0]',    Y
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 6, 6, 576)    55296       ['block_11_add[0][0]']           Y
#
#  block_12_expand_BN (BatchNorma  (None, 6, 6, 576)   2304        ['block_12_expand[0][0]']        Y
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 6, 6, 576)    0           ['block_12_expand_BN[0][0]']     Y
#
#  block_12_depthwise (DepthwiseC  (None, 6, 6, 576)   5184        ['block_12_expand_relu[0][0]']   Y
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 6, 6, 576)   2304        ['block_12_depthwise[0][0]']     Y
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 6, 6, 576)   0           ['block_12_depthwise_BN[0][0]']  Y
#
#  block_12_project (Conv2D)      (None, 6, 6, 96)     55296       ['block_12_depthwise_relu[0][0]  Y
#                                                                  ']
#
#  block_12_project_BN (BatchNorm  (None, 6, 6, 96)    384         ['block_12_project[0][0]']       Y
#  alization)
#
#  block_12_add (Add)             (None, 6, 6, 96)     0           ['block_11_add[0][0]',           Y
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 6, 6, 576)    55296       ['block_12_add[0][0]']           Y
#
#  block_13_expand_BN (BatchNorma  (None, 6, 6, 576)   2304        ['block_13_expand[0][0]']        Y
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 6, 6, 576)    0           ['block_13_expand_BN[0][0]']     Y
#
#  block_13_pad (ZeroPadding2D)   (None, 7, 7, 576)    0           ['block_13_expand_relu[0][0]']   Y
#
#  block_13_depthwise (DepthwiseC  (None, 3, 3, 576)   5184        ['block_13_pad[0][0]']           Y
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 3, 3, 576)   2304        ['block_13_depthwise[0][0]']     Y
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 3, 3, 576)   0           ['block_13_depthwise_BN[0][0]']  Y
#
#  block_13_project (Conv2D)      (None, 3, 3, 160)    92160       ['block_13_depthwise_relu[0][0]  Y
#                                                                  ']
#
#  block_13_project_BN (BatchNorm  (None, 3, 3, 160)   640         ['block_13_project[0][0]']       Y
#  alization)
#
#  block_14_expand (Conv2D)       (None, 3, 3, 960)    153600      ['block_13_project_BN[0][0]']    Y
#
#  block_14_expand_BN (BatchNorma  (None, 3, 3, 960)   3840        ['block_14_expand[0][0]']        Y
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 3, 3, 960)    0           ['block_14_expand_BN[0][0]']     Y
#
#  block_14_depthwise (DepthwiseC  (None, 3, 3, 960)   8640        ['block_14_expand_relu[0][0]']   Y
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 3, 3, 960)   3840        ['block_14_depthwise[0][0]']     Y
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 3, 3, 960)   0           ['block_14_depthwise_BN[0][0]']  Y
#
#  block_14_project (Conv2D)      (None, 3, 3, 160)    153600      ['block_14_depthwise_relu[0][0]  Y
#                                                                  ']
#
#  block_14_project_BN (BatchNorm  (None, 3, 3, 160)   640         ['block_14_project[0][0]']       Y
#  alization)
#
#  block_14_add (Add)             (None, 3, 3, 160)    0           ['block_13_project_BN[0][0]',    Y
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 3, 3, 960)    153600      ['block_14_add[0][0]']           Y
#
#  block_15_expand_BN (BatchNorma  (None, 3, 3, 960)   3840        ['block_15_expand[0][0]']        Y
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 3, 3, 960)    0           ['block_15_expand_BN[0][0]']     Y
#
#  block_15_depthwise (DepthwiseC  (None, 3, 3, 960)   8640        ['block_15_expand_relu[0][0]']   Y
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 3, 3, 960)   3840        ['block_15_depthwise[0][0]']     Y
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 3, 3, 960)   0           ['block_15_depthwise_BN[0][0]']  Y
#
#  block_15_project (Conv2D)      (None, 3, 3, 160)    153600      ['block_15_depthwise_relu[0][0]  Y
#                                                                  ']
#
#  block_15_project_BN (BatchNorm  (None, 3, 3, 160)   640         ['block_15_project[0][0]']       Y
#  alization)
#
#  block_15_add (Add)             (None, 3, 3, 160)    0           ['block_14_add[0][0]',           Y
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 3, 3, 960)    153600      ['block_15_add[0][0]']           Y
#
#  block_16_expand_BN (BatchNorma  (None, 3, 3, 960)   3840        ['block_16_expand[0][0]']        Y
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 3, 3, 960)    0           ['block_16_expand_BN[0][0]']     Y
#
#  block_16_depthwise (DepthwiseC  (None, 3, 3, 960)   8640        ['block_16_expand_relu[0][0]']   Y
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 3, 3, 960)   3840        ['block_16_depthwise[0][0]']     Y
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 3, 3, 960)   0           ['block_16_depthwise_BN[0][0]']  Y
#
#  block_16_project (Conv2D)      (None, 3, 3, 320)    307200      ['block_16_depthwise_relu[0][0]  Y
#                                                                  ']
#
#  block_16_project_BN (BatchNorm  (None, 3, 3, 320)   1280        ['block_16_project[0][0]']       Y
#  alization)
#
#  Conv_1 (Conv2D)                (None, 3, 3, 1280)   409600      ['block_16_project_BN[0][0]']    Y
#
#  Conv_1_bn (BatchNormalization)  (None, 3, 3, 1280)  5120        ['Conv_1[0][0]']                 Y
#
#  out_relu (ReLU)                (None, 3, 3, 1280)   0           ['Conv_1_bn[0][0]']              Y
#
#  global_average_pooling2d (Glob  (None, 1280)        0           ['out_relu[0][0]']               Y
#  alAveragePooling2D)
#
#  layer_normalization (LayerNorm  (None, 1280)        2560        ['global_average_pooling2d[0][0  Y
#  alization)                                                      ]']
#
#  dense (Dense)                  (None, 10)           12810       ['layer_normalization[0][0]']    Y
#
# =============================================================================================================
# Total params: 2,273,354
# Trainable params: 2,239,242
# Non-trainable params: 34,112
# _____________________________________________________________________________________________________________

# %% [markdown]
# ### 모델 컴파일
#
# 모델을 훈련할 준비가 되기 전에 몇 가지 설정이 더 필요합니다. 다음은 모델의 [*컴파일*](https://www.tensorflow.org/api_docs/python/tf/keras/Model#compile) 단계에서 추가됩니다.
#
# - [*손실 함수*](https://www.tensorflow.org/api_docs/python/tf/keras/losses) - 훈련 중 모델이 얼마나 정확한지 측정합니다. 모델을 올바른 방향으로 "조정"하려면 이 함수를 최소화해야 합니다.
# - [*옵티마이저*](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers) - 모델이 인식하는 데이터와 해당 손실 함수를 기반으로 모델이 업데이트되는 방식입니다.
# - [*메트릭*](https://www.tensorflow.org/api_docs/python/tf/keras/metrics) — 훈련 및 테스트 단계를 모니터링하는 데 사용됩니다. 다음 예에서는 올바르게 분류된 이미지의 비율인 *정확도*를 사용합니다.

# %%
model.compile(optimizer=tf.optimizers.Adam(learning_rate=1e-03),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=[
                  tf.keras.metrics.SparseCategoricalAccuracy(),
              ])

# %% [markdown]
# ## 모델 훈련
#
# 신경망 모델을 훈련하려면 다음 단계가 필요합니다.
#
# 1. 훈련 데이터를 모델에 주입합니다-이 예에서는 `train_images`와 `train_labels` 배열입니다.
# 2. 모델이 이미지와 레이블을 매핑하는 방법을 배웁니다.
# 3. 테스트 세트에 대한 모델의 예측을 만듭니다-이 예에서는 `test_images` 배열입니다. 이 예측이 `test_labels` 배열의 레이블과 맞는지 확인합니다.
# 4. 예측이 `test_labels` 배열의 레이블과 일치하는지 확인합니다.

# %% [markdown]
# ### 모델 피드
#
# 훈련을 시작하려면 [`model.fit`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit) 메서드를 호출합니다. 모델을 훈련 데이터에 "맞추기(fit)" 때문에 이렇게 불립니다.

# %%
history  = model.fit(datasets_train, epochs=20, validation_data=datasets_test)
# Out:
# Epoch 1/20
# 391/391 [==============================] - 74s 133ms/step - loss: 1.2072 - sparse_categorical_accuracy: 0.6121 - val_loss: 3.5535 - val_sparse_categorical_accuracy: 0.1818
# Epoch 2/20
# 391/391 [==============================] - 52s 130ms/step - loss: 0.8504 - sparse_categorical_accuracy: 0.7125 - val_loss: 4.1377 - val_sparse_categorical_accuracy: 0.2685
# Epoch 3/20
# 391/391 [==============================] - 52s 130ms/step - loss: 0.7690 - sparse_categorical_accuracy: 0.7368 - val_loss: 2.2529 - val_sparse_categorical_accuracy: 0.4196
# Epoch 4/20
# 391/391 [==============================] - 52s 130ms/step - loss: 0.7200 - sparse_categorical_accuracy: 0.7535 - val_loss: 3.2861 - val_sparse_categorical_accuracy: 0.2855
# Epoch 5/20
# 391/391 [==============================] - 52s 130ms/step - loss: 0.6869 - sparse_categorical_accuracy: 0.7642 - val_loss: 3.9432 - val_sparse_categorical_accuracy: 0.2162
# Epoch 6/20
# 391/391 [==============================] - 51s 129ms/step - loss: 0.6619 - sparse_categorical_accuracy: 0.7727 - val_loss: 1.8350 - val_sparse_categorical_accuracy: 0.5488
# Epoch 7/20
# 391/391 [==============================] - 52s 130ms/step - loss: 0.6476 - sparse_categorical_accuracy: 0.7795 - val_loss: 2.1724 - val_sparse_categorical_accuracy: 0.5033
# Epoch 8/20
# 391/391 [==============================] - 52s 130ms/step - loss: 0.6268 - sparse_categorical_accuracy: 0.7856 - val_loss: 1.2610 - val_sparse_categorical_accuracy: 0.6669
# Epoch 9/20
# 391/391 [==============================] - 52s 129ms/step - loss: 0.6077 - sparse_categorical_accuracy: 0.7904 - val_loss: 1.3037 - val_sparse_categorical_accuracy: 0.6684
# Epoch 10/20
# 391/391 [==============================] - 52s 129ms/step - loss: 0.5960 - sparse_categorical_accuracy: 0.7961 - val_loss: 1.5108 - val_sparse_categorical_accuracy: 0.6411
# Epoch 11/20
# 391/391 [==============================] - 52s 130ms/step - loss: 0.5750 - sparse_categorical_accuracy: 0.8035 - val_loss: 0.9755 - val_sparse_categorical_accuracy: 0.7282
# Epoch 12/20
# 391/391 [==============================] - 52s 131ms/step - loss: 0.5658 - sparse_categorical_accuracy: 0.8039 - val_loss: 1.7968 - val_sparse_categorical_accuracy: 0.6000
# Epoch 13/20
# 391/391 [==============================] - 52s 130ms/step - loss: 0.5549 - sparse_categorical_accuracy: 0.8093 - val_loss: 0.9756 - val_sparse_categorical_accuracy: 0.7487
# Epoch 14/20
# 391/391 [==============================] - 52s 130ms/step - loss: 0.5437 - sparse_categorical_accuracy: 0.8140 - val_loss: 1.0510 - val_sparse_categorical_accuracy: 0.7125
# Epoch 15/20
# 391/391 [==============================] - 52s 130ms/step - loss: 0.5362 - sparse_categorical_accuracy: 0.8169 - val_loss: 0.7630 - val_sparse_categorical_accuracy: 0.7888
# Epoch 16/20
# 391/391 [==============================] - 52s 130ms/step - loss: 0.5226 - sparse_categorical_accuracy: 0.8191 - val_loss: 0.7885 - val_sparse_categorical_accuracy: 0.7914
# Epoch 17/20
# 391/391 [==============================] - 52s 130ms/step - loss: 0.5170 - sparse_categorical_accuracy: 0.8230 - val_loss: 0.9919 - val_sparse_categorical_accuracy: 0.7300
# Epoch 18/20
# 391/391 [==============================] - 52s 130ms/step - loss: 0.5092 - sparse_categorical_accuracy: 0.8249 - val_loss: 1.2269 - val_sparse_categorical_accuracy: 0.7199
# Epoch 19/20
# 391/391 [==============================] - 52s 130ms/step - loss: 0.4940 - sparse_categorical_accuracy: 0.8291 - val_loss: 0.9891 - val_sparse_categorical_accuracy: 0.7442
# Epoch 20/20
# 391/391 [==============================] - 52s 130ms/step - loss: 0.4851 - sparse_categorical_accuracy: 0.8325 - val_loss: 1.2537 - val_sparse_categorical_accuracy: 0.7088

# %%
plt.plot(history.history['sparse_categorical_accuracy'], label='accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %% [markdown]
# ## 미세 조정

# %% [markdown]
# ### 컨볼루션 베이스 모델 고정하기

# %%
for idx, layer in enumerate(model.layers):
    print("{:<5d}: {}".format(idx, layer.name))
# Out:
# 0    : input_1
# 1    : Conv1
# 2    : bn_Conv1
# 3    : Conv1_relu
# 4    : expanded_conv_depthwise
# 5    : expanded_conv_depthwise_BN
# 6    : expanded_conv_depthwise_relu
# 7    : expanded_conv_project
# 8    : expanded_conv_project_BN
# 9    : block_1_expand
# 10   : block_1_expand_BN
# 11   : block_1_expand_relu
# 12   : block_1_pad
# 13   : block_1_depthwise
# 14   : block_1_depthwise_BN
# 15   : block_1_depthwise_relu
# 16   : block_1_project
# 17   : block_1_project_BN
# 18   : block_2_expand
# 19   : block_2_expand_BN
# 20   : block_2_expand_relu
# 21   : block_2_depthwise
# 22   : block_2_depthwise_BN
# 23   : block_2_depthwise_relu
# 24   : block_2_project
# 25   : block_2_project_BN
# 26   : block_2_add
# 27   : block_3_expand
# 28   : block_3_expand_BN
# 29   : block_3_expand_relu
# 30   : block_3_pad
# 31   : block_3_depthwise
# 32   : block_3_depthwise_BN
# 33   : block_3_depthwise_relu
# 34   : block_3_project
# 35   : block_3_project_BN
# 36   : block_4_expand
# 37   : block_4_expand_BN
# 38   : block_4_expand_relu
# 39   : block_4_depthwise
# 40   : block_4_depthwise_BN
# 41   : block_4_depthwise_relu
# 42   : block_4_project
# 43   : block_4_project_BN
# 44   : block_4_add
# 45   : block_5_expand
# 46   : block_5_expand_BN
# 47   : block_5_expand_relu
# 48   : block_5_depthwise
# 49   : block_5_depthwise_BN
# 50   : block_5_depthwise_relu
# 51   : block_5_project
# 52   : block_5_project_BN
# 53   : block_5_add
# 54   : block_6_expand
# 55   : block_6_expand_BN
# 56   : block_6_expand_relu
# 57   : block_6_pad
# 58   : block_6_depthwise
# 59   : block_6_depthwise_BN
# 60   : block_6_depthwise_relu
# 61   : block_6_project
# 62   : block_6_project_BN
# 63   : block_7_expand
# 64   : block_7_expand_BN
# 65   : block_7_expand_relu
# 66   : block_7_depthwise
# 67   : block_7_depthwise_BN
# 68   : block_7_depthwise_relu
# 69   : block_7_project
# 70   : block_7_project_BN
# 71   : block_7_add
# 72   : block_8_expand
# 73   : block_8_expand_BN
# 74   : block_8_expand_relu
# 75   : block_8_depthwise
# 76   : block_8_depthwise_BN
# 77   : block_8_depthwise_relu
# 78   : block_8_project
# 79   : block_8_project_BN
# 80   : block_8_add
# 81   : block_9_expand
# 82   : block_9_expand_BN
# 83   : block_9_expand_relu
# 84   : block_9_depthwise
# 85   : block_9_depthwise_BN
# 86   : block_9_depthwise_relu
# 87   : block_9_project
# 88   : block_9_project_BN
# 89   : block_9_add
# 90   : block_10_expand
# 91   : block_10_expand_BN
# 92   : block_10_expand_relu
# 93   : block_10_depthwise
# 94   : block_10_depthwise_BN
# 95   : block_10_depthwise_relu
# 96   : block_10_project
# 97   : block_10_project_BN
# 98   : block_11_expand
# 99   : block_11_expand_BN
# 100  : block_11_expand_relu
# 101  : block_11_depthwise
# 102  : block_11_depthwise_BN
# 103  : block_11_depthwise_relu
# 104  : block_11_project
# 105  : block_11_project_BN
# 106  : block_11_add
# 107  : block_12_expand
# 108  : block_12_expand_BN
# 109  : block_12_expand_relu
# 110  : block_12_depthwise
# 111  : block_12_depthwise_BN
# 112  : block_12_depthwise_relu
# 113  : block_12_project
# 114  : block_12_project_BN
# 115  : block_12_add
# 116  : block_13_expand
# 117  : block_13_expand_BN
# 118  : block_13_expand_relu
# 119  : block_13_pad
# 120  : block_13_depthwise
# 121  : block_13_depthwise_BN
# 122  : block_13_depthwise_relu
# 123  : block_13_project
# 124  : block_13_project_BN
# 125  : block_14_expand
# 126  : block_14_expand_BN
# 127  : block_14_expand_relu
# 128  : block_14_depthwise
# 129  : block_14_depthwise_BN
# 130  : block_14_depthwise_relu
# 131  : block_14_project
# 132  : block_14_project_BN
# 133  : block_14_add
# 134  : block_15_expand
# 135  : block_15_expand_BN
# 136  : block_15_expand_relu
# 137  : block_15_depthwise
# 138  : block_15_depthwise_BN
# 139  : block_15_depthwise_relu
# 140  : block_15_project
# 141  : block_15_project_BN
# 142  : block_15_add
# 143  : block_16_expand
# 144  : block_16_expand_BN
# 145  : block_16_expand_relu
# 146  : block_16_depthwise
# 147  : block_16_depthwise_BN
# 148  : block_16_depthwise_relu
# 149  : block_16_project
# 150  : block_16_project_BN
# 151  : Conv_1
# 152  : Conv_1_bn
# 153  : out_relu
# 154  : global_average_pooling2d
# 155  : layer_normalization
# 156  : dense

# %%
for layer in model.layers[:134]:
      layer.trainable = False

# %%
model.compile(optimizer=tf.optimizers.Adam(learning_rate=1e-03),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=[
                  tf.keras.metrics.SparseCategoricalAccuracy(),
              ])

# %%
model.summary(show_trainable=True)
# Out:
# Model: "model"
# _____________________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to                     Trainable
# =============================================================================================================
#  input_1 (InputLayer)           [(None, 96, 96, 3)]  0           []                               N
#
#  Conv1 (Conv2D)                 (None, 48, 48, 32)   864         ['input_1[0][0]']                N
#
#  bn_Conv1 (BatchNormalization)  (None, 48, 48, 32)   128         ['Conv1[0][0]']                  N
#
#  Conv1_relu (ReLU)              (None, 48, 48, 32)   0           ['bn_Conv1[0][0]']               N
#
#  expanded_conv_depthwise (Depth  (None, 48, 48, 32)  288         ['Conv1_relu[0][0]']             N
#  wiseConv2D)
#
#  expanded_conv_depthwise_BN (Ba  (None, 48, 48, 32)  128         ['expanded_conv_depthwise[0][0]  N
#  tchNormalization)                                               ']
#
#  expanded_conv_depthwise_relu (  (None, 48, 48, 32)  0           ['expanded_conv_depthwise_BN[0]  N
#  ReLU)                                                           [0]']
#
#  expanded_conv_project (Conv2D)  (None, 48, 48, 16)  512         ['expanded_conv_depthwise_relu[  N
#                                                                  0][0]']
#
#  expanded_conv_project_BN (Batc  (None, 48, 48, 16)  64          ['expanded_conv_project[0][0]']  N
#  hNormalization)
#
#  block_1_expand (Conv2D)        (None, 48, 48, 96)   1536        ['expanded_conv_project_BN[0][0  N
#                                                                  ]']
#
#  block_1_expand_BN (BatchNormal  (None, 48, 48, 96)  384         ['block_1_expand[0][0]']         N
#  ization)
#
#  block_1_expand_relu (ReLU)     (None, 48, 48, 96)   0           ['block_1_expand_BN[0][0]']      N
#
#  block_1_pad (ZeroPadding2D)    (None, 49, 49, 96)   0           ['block_1_expand_relu[0][0]']    N
#
#  block_1_depthwise (DepthwiseCo  (None, 24, 24, 96)  864         ['block_1_pad[0][0]']            N
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 24, 24, 96)  384         ['block_1_depthwise[0][0]']      N
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 24, 24, 96)   0           ['block_1_depthwise_BN[0][0]']   N
#
#  block_1_project (Conv2D)       (None, 24, 24, 24)   2304        ['block_1_depthwise_relu[0][0]'  N
#                                                                  ]
#
#  block_1_project_BN (BatchNorma  (None, 24, 24, 24)  96          ['block_1_project[0][0]']        N
#  lization)
#
#  block_2_expand (Conv2D)        (None, 24, 24, 144)  3456        ['block_1_project_BN[0][0]']     N
#
#  block_2_expand_BN (BatchNormal  (None, 24, 24, 144)  576        ['block_2_expand[0][0]']         N
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 24, 24, 144)  0           ['block_2_expand_BN[0][0]']      N
#
#  block_2_depthwise (DepthwiseCo  (None, 24, 24, 144)  1296       ['block_2_expand_relu[0][0]']    N
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 24, 24, 144)  576        ['block_2_depthwise[0][0]']      N
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 24, 24, 144)  0           ['block_2_depthwise_BN[0][0]']   N
#
#  block_2_project (Conv2D)       (None, 24, 24, 24)   3456        ['block_2_depthwise_relu[0][0]'  N
#                                                                  ]
#
#  block_2_project_BN (BatchNorma  (None, 24, 24, 24)  96          ['block_2_project[0][0]']        N
#  lization)
#
#  block_2_add (Add)              (None, 24, 24, 24)   0           ['block_1_project_BN[0][0]',     N
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 24, 24, 144)  3456        ['block_2_add[0][0]']            N
#
#  block_3_expand_BN (BatchNormal  (None, 24, 24, 144)  576        ['block_3_expand[0][0]']         N
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 24, 24, 144)  0           ['block_3_expand_BN[0][0]']      N
#
#  block_3_pad (ZeroPadding2D)    (None, 25, 25, 144)  0           ['block_3_expand_relu[0][0]']    N
#
#  block_3_depthwise (DepthwiseCo  (None, 12, 12, 144)  1296       ['block_3_pad[0][0]']            N
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 12, 12, 144)  576        ['block_3_depthwise[0][0]']      N
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 12, 12, 144)  0           ['block_3_depthwise_BN[0][0]']   N
#
#  block_3_project (Conv2D)       (None, 12, 12, 32)   4608        ['block_3_depthwise_relu[0][0]'  N
#                                                                  ]
#
#  block_3_project_BN (BatchNorma  (None, 12, 12, 32)  128         ['block_3_project[0][0]']        N
#  lization)
#
#  block_4_expand (Conv2D)        (None, 12, 12, 192)  6144        ['block_3_project_BN[0][0]']     N
#
#  block_4_expand_BN (BatchNormal  (None, 12, 12, 192)  768        ['block_4_expand[0][0]']         N
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 12, 12, 192)  0           ['block_4_expand_BN[0][0]']      N
#
#  block_4_depthwise (DepthwiseCo  (None, 12, 12, 192)  1728       ['block_4_expand_relu[0][0]']    N
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 12, 12, 192)  768        ['block_4_depthwise[0][0]']      N
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 12, 12, 192)  0           ['block_4_depthwise_BN[0][0]']   N
#
#  block_4_project (Conv2D)       (None, 12, 12, 32)   6144        ['block_4_depthwise_relu[0][0]'  N
#                                                                  ]
#
#  block_4_project_BN (BatchNorma  (None, 12, 12, 32)  128         ['block_4_project[0][0]']        N
#  lization)
#
#  block_4_add (Add)              (None, 12, 12, 32)   0           ['block_3_project_BN[0][0]',     N
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 12, 12, 192)  6144        ['block_4_add[0][0]']            N
#
#  block_5_expand_BN (BatchNormal  (None, 12, 12, 192)  768        ['block_5_expand[0][0]']         N
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 12, 12, 192)  0           ['block_5_expand_BN[0][0]']      N
#
#  block_5_depthwise (DepthwiseCo  (None, 12, 12, 192)  1728       ['block_5_expand_relu[0][0]']    N
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 12, 12, 192)  768        ['block_5_depthwise[0][0]']      N
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 12, 12, 192)  0           ['block_5_depthwise_BN[0][0]']   N
#
#  block_5_project (Conv2D)       (None, 12, 12, 32)   6144        ['block_5_depthwise_relu[0][0]'  N
#                                                                  ]
#
#  block_5_project_BN (BatchNorma  (None, 12, 12, 32)  128         ['block_5_project[0][0]']        N
#  lization)
#
#  block_5_add (Add)              (None, 12, 12, 32)   0           ['block_4_add[0][0]',            N
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 12, 12, 192)  6144        ['block_5_add[0][0]']            N
#
#  block_6_expand_BN (BatchNormal  (None, 12, 12, 192)  768        ['block_6_expand[0][0]']         N
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 12, 12, 192)  0           ['block_6_expand_BN[0][0]']      N
#
#  block_6_pad (ZeroPadding2D)    (None, 13, 13, 192)  0           ['block_6_expand_relu[0][0]']    N
#
#  block_6_depthwise (DepthwiseCo  (None, 6, 6, 192)   1728        ['block_6_pad[0][0]']            N
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 6, 6, 192)   768         ['block_6_depthwise[0][0]']      N
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 6, 6, 192)    0           ['block_6_depthwise_BN[0][0]']   N
#
#  block_6_project (Conv2D)       (None, 6, 6, 64)     12288       ['block_6_depthwise_relu[0][0]'  N
#                                                                  ]
#
#  block_6_project_BN (BatchNorma  (None, 6, 6, 64)    256         ['block_6_project[0][0]']        N
#  lization)
#
#  block_7_expand (Conv2D)        (None, 6, 6, 384)    24576       ['block_6_project_BN[0][0]']     N
#
#  block_7_expand_BN (BatchNormal  (None, 6, 6, 384)   1536        ['block_7_expand[0][0]']         N
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 6, 6, 384)    0           ['block_7_expand_BN[0][0]']      N
#
#  block_7_depthwise (DepthwiseCo  (None, 6, 6, 384)   3456        ['block_7_expand_relu[0][0]']    N
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 6, 6, 384)   1536        ['block_7_depthwise[0][0]']      N
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 6, 6, 384)    0           ['block_7_depthwise_BN[0][0]']   N
#
#  block_7_project (Conv2D)       (None, 6, 6, 64)     24576       ['block_7_depthwise_relu[0][0]'  N
#                                                                  ]
#
#  block_7_project_BN (BatchNorma  (None, 6, 6, 64)    256         ['block_7_project[0][0]']        N
#  lization)
#
#  block_7_add (Add)              (None, 6, 6, 64)     0           ['block_6_project_BN[0][0]',     N
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 6, 6, 384)    24576       ['block_7_add[0][0]']            N
#
#  block_8_expand_BN (BatchNormal  (None, 6, 6, 384)   1536        ['block_8_expand[0][0]']         N
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 6, 6, 384)    0           ['block_8_expand_BN[0][0]']      N
#
#  block_8_depthwise (DepthwiseCo  (None, 6, 6, 384)   3456        ['block_8_expand_relu[0][0]']    N
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 6, 6, 384)   1536        ['block_8_depthwise[0][0]']      N
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 6, 6, 384)    0           ['block_8_depthwise_BN[0][0]']   N
#
#  block_8_project (Conv2D)       (None, 6, 6, 64)     24576       ['block_8_depthwise_relu[0][0]'  N
#                                                                  ]
#
#  block_8_project_BN (BatchNorma  (None, 6, 6, 64)    256         ['block_8_project[0][0]']        N
#  lization)
#
#  block_8_add (Add)              (None, 6, 6, 64)     0           ['block_7_add[0][0]',            N
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 6, 6, 384)    24576       ['block_8_add[0][0]']            N
#
#  block_9_expand_BN (BatchNormal  (None, 6, 6, 384)   1536        ['block_9_expand[0][0]']         N
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 6, 6, 384)    0           ['block_9_expand_BN[0][0]']      N
#
#  block_9_depthwise (DepthwiseCo  (None, 6, 6, 384)   3456        ['block_9_expand_relu[0][0]']    N
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 6, 6, 384)   1536        ['block_9_depthwise[0][0]']      N
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 6, 6, 384)    0           ['block_9_depthwise_BN[0][0]']   N
#
#  block_9_project (Conv2D)       (None, 6, 6, 64)     24576       ['block_9_depthwise_relu[0][0]'  N
#                                                                  ]
#
#  block_9_project_BN (BatchNorma  (None, 6, 6, 64)    256         ['block_9_project[0][0]']        N
#  lization)
#
#  block_9_add (Add)              (None, 6, 6, 64)     0           ['block_8_add[0][0]',            N
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 6, 6, 384)    24576       ['block_9_add[0][0]']            N
#
#  block_10_expand_BN (BatchNorma  (None, 6, 6, 384)   1536        ['block_10_expand[0][0]']        N
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 6, 6, 384)    0           ['block_10_expand_BN[0][0]']     N
#
#  block_10_depthwise (DepthwiseC  (None, 6, 6, 384)   3456        ['block_10_expand_relu[0][0]']   N
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 6, 6, 384)   1536        ['block_10_depthwise[0][0]']     N
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 6, 6, 384)   0           ['block_10_depthwise_BN[0][0]']  N
#
#  block_10_project (Conv2D)      (None, 6, 6, 96)     36864       ['block_10_depthwise_relu[0][0]  N
#                                                                  ']
#
#  block_10_project_BN (BatchNorm  (None, 6, 6, 96)    384         ['block_10_project[0][0]']       N
#  alization)
#
#  block_11_expand (Conv2D)       (None, 6, 6, 576)    55296       ['block_10_project_BN[0][0]']    N
#
#  block_11_expand_BN (BatchNorma  (None, 6, 6, 576)   2304        ['block_11_expand[0][0]']        N
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 6, 6, 576)    0           ['block_11_expand_BN[0][0]']     N
#
#  block_11_depthwise (DepthwiseC  (None, 6, 6, 576)   5184        ['block_11_expand_relu[0][0]']   N
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 6, 6, 576)   2304        ['block_11_depthwise[0][0]']     N
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 6, 6, 576)   0           ['block_11_depthwise_BN[0][0]']  N
#
#  block_11_project (Conv2D)      (None, 6, 6, 96)     55296       ['block_11_depthwise_relu[0][0]  N
#                                                                  ']
#
#  block_11_project_BN (BatchNorm  (None, 6, 6, 96)    384         ['block_11_project[0][0]']       N
#  alization)
#
#  block_11_add (Add)             (None, 6, 6, 96)     0           ['block_10_project_BN[0][0]',    N
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 6, 6, 576)    55296       ['block_11_add[0][0]']           N
#
#  block_12_expand_BN (BatchNorma  (None, 6, 6, 576)   2304        ['block_12_expand[0][0]']        N
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 6, 6, 576)    0           ['block_12_expand_BN[0][0]']     N
#
#  block_12_depthwise (DepthwiseC  (None, 6, 6, 576)   5184        ['block_12_expand_relu[0][0]']   N
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 6, 6, 576)   2304        ['block_12_depthwise[0][0]']     N
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 6, 6, 576)   0           ['block_12_depthwise_BN[0][0]']  N
#
#  block_12_project (Conv2D)      (None, 6, 6, 96)     55296       ['block_12_depthwise_relu[0][0]  N
#                                                                  ']
#
#  block_12_project_BN (BatchNorm  (None, 6, 6, 96)    384         ['block_12_project[0][0]']       N
#  alization)
#
#  block_12_add (Add)             (None, 6, 6, 96)     0           ['block_11_add[0][0]',           N
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 6, 6, 576)    55296       ['block_12_add[0][0]']           N
#
#  block_13_expand_BN (BatchNorma  (None, 6, 6, 576)   2304        ['block_13_expand[0][0]']        N
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 6, 6, 576)    0           ['block_13_expand_BN[0][0]']     N
#
#  block_13_pad (ZeroPadding2D)   (None, 7, 7, 576)    0           ['block_13_expand_relu[0][0]']   N
#
#  block_13_depthwise (DepthwiseC  (None, 3, 3, 576)   5184        ['block_13_pad[0][0]']           N
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 3, 3, 576)   2304        ['block_13_depthwise[0][0]']     N
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 3, 3, 576)   0           ['block_13_depthwise_BN[0][0]']  N
#
#  block_13_project (Conv2D)      (None, 3, 3, 160)    92160       ['block_13_depthwise_relu[0][0]  N
#                                                                  ']
#
#  block_13_project_BN (BatchNorm  (None, 3, 3, 160)   640         ['block_13_project[0][0]']       N
#  alization)
#
#  block_14_expand (Conv2D)       (None, 3, 3, 960)    153600      ['block_13_project_BN[0][0]']    N
#
#  block_14_expand_BN (BatchNorma  (None, 3, 3, 960)   3840        ['block_14_expand[0][0]']        N
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 3, 3, 960)    0           ['block_14_expand_BN[0][0]']     N
#
#  block_14_depthwise (DepthwiseC  (None, 3, 3, 960)   8640        ['block_14_expand_relu[0][0]']   N
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 3, 3, 960)   3840        ['block_14_depthwise[0][0]']     N
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 3, 3, 960)   0           ['block_14_depthwise_BN[0][0]']  N
#
#  block_14_project (Conv2D)      (None, 3, 3, 160)    153600      ['block_14_depthwise_relu[0][0]  N
#                                                                  ']
#
#  block_14_project_BN (BatchNorm  (None, 3, 3, 160)   640         ['block_14_project[0][0]']       N
#  alization)
#
#  block_14_add (Add)             (None, 3, 3, 160)    0           ['block_13_project_BN[0][0]',    N
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 3, 3, 960)    153600      ['block_14_add[0][0]']           Y
#
#  block_15_expand_BN (BatchNorma  (None, 3, 3, 960)   3840        ['block_15_expand[0][0]']        Y
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 3, 3, 960)    0           ['block_15_expand_BN[0][0]']     Y
#
#  block_15_depthwise (DepthwiseC  (None, 3, 3, 960)   8640        ['block_15_expand_relu[0][0]']   Y
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 3, 3, 960)   3840        ['block_15_depthwise[0][0]']     Y
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 3, 3, 960)   0           ['block_15_depthwise_BN[0][0]']  Y
#
#  block_15_project (Conv2D)      (None, 3, 3, 160)    153600      ['block_15_depthwise_relu[0][0]  Y
#                                                                  ']
#
#  block_15_project_BN (BatchNorm  (None, 3, 3, 160)   640         ['block_15_project[0][0]']       Y
#  alization)
#
#  block_15_add (Add)             (None, 3, 3, 160)    0           ['block_14_add[0][0]',           Y
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 3, 3, 960)    153600      ['block_15_add[0][0]']           Y
#
#  block_16_expand_BN (BatchNorma  (None, 3, 3, 960)   3840        ['block_16_expand[0][0]']        Y
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 3, 3, 960)    0           ['block_16_expand_BN[0][0]']     Y
#
#  block_16_depthwise (DepthwiseC  (None, 3, 3, 960)   8640        ['block_16_expand_relu[0][0]']   Y
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 3, 3, 960)   3840        ['block_16_depthwise[0][0]']     Y
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 3, 3, 960)   0           ['block_16_depthwise_BN[0][0]']  Y
#
#  block_16_project (Conv2D)      (None, 3, 3, 320)    307200      ['block_16_depthwise_relu[0][0]  Y
#                                                                  ']
#
#  block_16_project_BN (BatchNorm  (None, 3, 3, 320)   1280        ['block_16_project[0][0]']       Y
#  alization)
#
#  Conv_1 (Conv2D)                (None, 3, 3, 1280)   409600      ['block_16_project_BN[0][0]']    Y
#
#  Conv_1_bn (BatchNormalization)  (None, 3, 3, 1280)  5120        ['Conv_1[0][0]']                 Y
#
#  out_relu (ReLU)                (None, 3, 3, 1280)   0           ['Conv_1_bn[0][0]']              Y
#
#  global_average_pooling2d (Glob  (None, 1280)        0           ['out_relu[0][0]']               Y
#  alAveragePooling2D)
#
#  layer_normalization (LayerNorm  (None, 1280)        2560        ['global_average_pooling2d[0][0  Y
#  alization)                                                      ]']
#
#  dense (Dense)                  (None, 10)           12810       ['layer_normalization[0][0]']    Y
#
# =============================================================================================================
# Total params: 2,273,354
# Trainable params: 1,221,450
# Non-trainable params: 1,051,904
# _____________________________________________________________________________________________________________

# %%
history_fine  = model.fit(datasets_train, epochs=20, validation_data=datasets_test)
# Out:
# Epoch 1/20
# 391/391 [==============================] - 40s 88ms/step - loss: 0.7575 - sparse_categorical_accuracy: 0.7391 - val_loss: 0.4884 - val_sparse_categorical_accuracy: 0.8448
# Epoch 2/20
# 391/391 [==============================] - 35s 86ms/step - loss: 0.6941 - sparse_categorical_accuracy: 0.7614 - val_loss: 0.4343 - val_sparse_categorical_accuracy: 0.8624
# Epoch 3/20
# 391/391 [==============================] - 35s 86ms/step - loss: 0.6828 - sparse_categorical_accuracy: 0.7651 - val_loss: 0.4147 - val_sparse_categorical_accuracy: 0.8676
# Epoch 4/20
# 391/391 [==============================] - 35s 86ms/step - loss: 0.6646 - sparse_categorical_accuracy: 0.7710 - val_loss: 0.4732 - val_sparse_categorical_accuracy: 0.8524
# Epoch 5/20
# 391/391 [==============================] - 35s 87ms/step - loss: 0.6623 - sparse_categorical_accuracy: 0.7719 - val_loss: 0.3850 - val_sparse_categorical_accuracy: 0.8749
# Epoch 6/20
# 391/391 [==============================] - 35s 86ms/step - loss: 0.6494 - sparse_categorical_accuracy: 0.7754 - val_loss: 0.4456 - val_sparse_categorical_accuracy: 0.8574
# Epoch 7/20
# 391/391 [==============================] - 35s 86ms/step - loss: 0.6422 - sparse_categorical_accuracy: 0.7799 - val_loss: 0.4898 - val_sparse_categorical_accuracy: 0.8464
# Epoch 8/20
# 391/391 [==============================] - 35s 86ms/step - loss: 0.6392 - sparse_categorical_accuracy: 0.7780 - val_loss: 0.4129 - val_sparse_categorical_accuracy: 0.8635
# Epoch 9/20
# 391/391 [==============================] - 35s 86ms/step - loss: 0.6328 - sparse_categorical_accuracy: 0.7809 - val_loss: 0.3834 - val_sparse_categorical_accuracy: 0.8724
# Epoch 10/20
# 391/391 [==============================] - 35s 86ms/step - loss: 0.6251 - sparse_categorical_accuracy: 0.7855 - val_loss: 0.4031 - val_sparse_categorical_accuracy: 0.8676
# Epoch 11/20
# 391/391 [==============================] - 35s 86ms/step - loss: 0.6261 - sparse_categorical_accuracy: 0.7830 - val_loss: 0.3870 - val_sparse_categorical_accuracy: 0.8710
# Epoch 12/20
# 391/391 [==============================] - 35s 86ms/step - loss: 0.6287 - sparse_categorical_accuracy: 0.7864 - val_loss: 0.3502 - val_sparse_categorical_accuracy: 0.8871
# Epoch 13/20
# 391/391 [==============================] - 35s 87ms/step - loss: 0.6176 - sparse_categorical_accuracy: 0.7868 - val_loss: 0.4047 - val_sparse_categorical_accuracy: 0.8718
# Epoch 14/20
# 391/391 [==============================] - 35s 87ms/step - loss: 0.6154 - sparse_categorical_accuracy: 0.7872 - val_loss: 0.3746 - val_sparse_categorical_accuracy: 0.8813
# Epoch 15/20
# 391/391 [==============================] - 35s 87ms/step - loss: 0.6072 - sparse_categorical_accuracy: 0.7910 - val_loss: 0.3572 - val_sparse_categorical_accuracy: 0.8840
# Epoch 16/20
# 391/391 [==============================] - 35s 86ms/step - loss: 0.6068 - sparse_categorical_accuracy: 0.7897 - val_loss: 0.3522 - val_sparse_categorical_accuracy: 0.8837
# Epoch 17/20
# 391/391 [==============================] - 35s 87ms/step - loss: 0.6039 - sparse_categorical_accuracy: 0.7904 - val_loss: 0.3405 - val_sparse_categorical_accuracy: 0.8899
# Epoch 18/20
# 391/391 [==============================] - 35s 86ms/step - loss: 0.6010 - sparse_categorical_accuracy: 0.7935 - val_loss: 0.3606 - val_sparse_categorical_accuracy: 0.8847
# Epoch 19/20
# 391/391 [==============================] - 35s 87ms/step - loss: 0.6034 - sparse_categorical_accuracy: 0.7918 - val_loss: 0.3416 - val_sparse_categorical_accuracy: 0.8913
# Epoch 20/20
# 391/391 [==============================] - 35s 86ms/step - loss: 0.6021 - sparse_categorical_accuracy: 0.7943 - val_loss: 0.3587 - val_sparse_categorical_accuracy: 0.8840

# %%
plt.plot(history.history['sparse_categorical_accuracy'] + history_fine.history['sparse_categorical_accuracy'], label='accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'] + history_fine.history['val_sparse_categorical_accuracy'], label = 'val_accuracy')
plt.plot([19.5, 19.5], [0.5, 1], label='Start Fine Tuning')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
