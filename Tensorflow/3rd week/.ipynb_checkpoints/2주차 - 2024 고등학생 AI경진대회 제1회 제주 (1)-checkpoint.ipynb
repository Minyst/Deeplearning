# %% [markdown]
# # 2주차 - 2024 고등학생 AI경진대회 제1회 제주

# %% [markdown]
# ![KakaoTalk_20230803_163633393.png](attachment:KakaoTalk_20230803_163633393.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %%
import os
import random

# %%
import numpy as np
import pandas as pd

# %%
from tqdm.auto import tqdm

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score

# %%
import tensorflow as tf
# Out:
# WARNING:tensorflow:From C:\Users\Owner\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
random.seed(42)
np.random.seed(42)
os.environ['PYTHONHASHSEED'] = "42"

os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 준비

# %% [markdown]
# ## 데이터 설명
#
# - train.csv [파일]
#     - ID : 신용카드를 보유한 고객의 고유 ID
#     - TARGET : 고객의 신용카드 연체 여부
#     - 성별
#     - 차량 소유 여부
#     - 부동산 소유 여부
#     - 자녀 수
#     - 연간 수입 : 단위 원
#     - 수입 유형
#     - 최종 학력
#     - 결혼 여부
#     - 주거 형태
#     - 거주지 인구 비율: 고객이 거주하는 지역 인근의 인구 비율 (범위 0~1)
#     - 휴대전화 소유 여부
#     - 업무용 휴대폰 소유 여부
#     - 이메일 소유 여부
#     - 직업
#     - 가족 구성원 수
#     - 산업군 : 고객이 종사하는 직종의 산업군
#     - 나이
#     - 근속연수
#     - 가입연수
#
#
# - test.csv [파일]
#         - ID : 신용카드를 보유한 고객의 고유 ID
#     - TARGET이 존재하지 않음
#
#
# - sample_submission.csv [파일] - 제출 양식
#     - ID : 신용카드를 보유한 고객의 고유 ID
#     - TARGET : 고객의 신용카드 연체 여부를 예측하여 기입

# %% [markdown]
# ---

# %% [markdown]
# ## 데이터 불러오기

# %% [markdown]
# ### train

# %%
train_df = pd.read_csv("train.csv")

# %%
train_df.head()
# Out:
#             ID  TARGET  성별  차량 소유 여부  부동산 소유 여부  자녀 수       연간 수입  수입 유형  \
# 0  TRAIN_00000       0  여성         1          1     2  18054000.0  연금수령자
# 1  TRAIN_00001       0  남성         1          0     0  59472000.0    근로자
# 2  TRAIN_00002       0  여성         0          1     0  29736000.0    근로자
# 3  TRAIN_00003       0  여성         1          0     1  38232000.0     기타
# 4  TRAIN_00004       0  여성         0          1     0  26550000.0    근로자
#
#        최종 학력 결혼 여부  ... 거주지 인구 비율  휴대전화 소유 여부  업무용 휴대전화 소유 여부  이메일 소유 여부  \
# 0    고등학교 졸업    기혼  ...  0.004960           1               0          0
# 1  대학교 졸업 이상    기혼  ...  0.018029           1               1          0
# 2    고등학교 졸업    기혼  ...  0.010500           1               1          0
# 3    고등학교 졸업    기혼  ...  0.004849           1               1          0
# 4    고등학교 졸업    기혼  ...  0.025164           1               1          0
#
#         직업 가족 구성원 수   산업군  나이  근속연수  가입연수
# 0  Unknown      4.0  기타 1  39  1000  23.0
# 1      기술직      2.0  사업 1  45     4  16.0
# 2   단순 노동자      2.0  사업 0  32     3   9.0
# 3  Unknown      3.0  산업 4  34     6  12.0
# 4  Unknown      2.0  사업 2  38     0   4.0
#
# [5 rows x 21 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              60000 non-null  object
#  1   TARGET          60000 non-null  int64
#  2   성별              60000 non-null  object
#  3   차량 소유 여부        60000 non-null  int64
#  4   부동산 소유 여부       60000 non-null  int64
#  5   자녀 수            60000 non-null  int64
#  6   연간 수입           60000 non-null  float64
#  7   수입 유형           60000 non-null  object
#  8   최종 학력           60000 non-null  object
#  9   결혼 여부           60000 non-null  object
#  10  주거 형태           60000 non-null  object
#  11  거주지 인구 비율       60000 non-null  float64
#  12  휴대전화 소유 여부      60000 non-null  int64
#  13  업무용 휴대전화 소유 여부  60000 non-null  int64
#  14  이메일 소유 여부       60000 non-null  int64
#  15  직업              60000 non-null  object
#  16  가족 구성원 수        60000 non-null  float64
#  17  산업군             60000 non-null  object
#  18  나이              60000 non-null  int64
#  19  근속연수            60000 non-null  int64
#  20  가입연수            60000 non-null  float64
# dtypes: float64(4), int64(9), object(8)
# memory usage: 9.6+ MB

# %%
train_df.describe()
# Out:
#              TARGET      차량 소유 여부     부동산 소유 여부          자녀 수         연간 수입  \
# count  60000.000000  60000.000000  60000.000000  60000.000000  6.000000e+04
# mean       0.107133      0.337517      0.708633      0.412050  3.983699e+07
# std        0.309285      0.472867      0.454396      0.723998  2.472331e+07
# min        0.000000      0.000000      0.000000      0.000000  6.265800e+06
# 25%        0.000000      0.000000      0.000000      0.000000  2.655000e+07
# 50%        0.000000      0.000000      1.000000      0.000000  3.504600e+07
# 75%        0.000000      1.000000      1.000000      1.000000  4.779000e+07
# max        1.000000      1.000000      1.000000     19.000000  2.124000e+09
#
#           거주지 인구 비율    휴대전화 소유 여부  업무용 휴대전화 소유 여부     이메일 소유 여부      가족 구성원 수  \
# count  60000.000000  60000.000000    60000.000000  60000.000000  60000.000000
# mean       0.020880      0.999983        0.812033      0.056350      2.155767
# std        0.013850      0.004082        0.390689      0.230598      0.908213
# min        0.000533      0.000000        0.000000      0.000000      1.000000
# 25%        0.010006      1.000000        1.000000      0.000000      2.000000
# 50%        0.018850      1.000000        1.000000      0.000000      2.000000
# 75%        0.028663      1.000000        1.000000      0.000000      3.000000
# max        0.072508      1.000000        1.000000      1.000000     20.000000
#
#                  나이          근속연수          가입연수
# count  60000.000000  60000.000000  60000.000000
# mean      44.021183    192.906833     13.271833
# std       11.852450    388.292796      9.727011
# min       21.000000      0.000000      0.000000
# 25%       34.000000      2.000000      5.000000
# 50%       43.000000      6.000000     12.000000
# 75%       54.000000     16.000000     20.000000
# max       69.000000   1000.000000     58.000000

# %%
train_df.TARGET.value_counts()
# Out:
# 0    53572
# 1     6428
# Name: TARGET, dtype: int64

# %% [markdown]
# ### test

# %%
test_df = pd.read_csv("test.csv")

# %%
test_df.head()
# Out:
#            ID  성별  차량 소유 여부  부동산 소유 여부  자녀 수       연간 수입  수입 유형      최종 학력  \
# 0  TEST_00000  남성         0          0     2  37170000.0    근로자     대학교 중퇴
# 1  TEST_00001  남성         0          0     0  47790000.0    근로자  대학교 졸업 이상
# 2  TEST_00002  남성         1          1     1  37170000.0    공무원    고등학교 졸업
# 3  TEST_00003  여성         0          1     0  31860000.0  연금수령자    고등학교 졸업
# 4  TEST_00004  여성         0          1     2  19116000.0    근로자    고등학교 졸업
#
#   결혼 여부     주거 형태  거주지 인구 비율  휴대전화 소유 여부  업무용 휴대전화 소유 여부  이메일 소유 여부  \
# 0    기혼  주택 / 아파트   0.006296           1               1          0
# 1    기혼  주택 / 아파트   0.004960           1               1          0
# 2    기혼  주택 / 아파트   0.026392           1               1          0
# 3    기혼  주택 / 아파트   0.014464           1               0          0
# 4    기혼      공공분양   0.031329           1               1          0
#
#           직업  가족 구성원 수    산업군  나이  근속연수  가입연수
# 0     핵심 노동자       4.0   기타 0  27     2   8.0
# 1        관리직       2.0     정부  40     8  11.0
# 2        관리직       3.0  국가 안보  43    15  14.0
# 3    Unknown       2.0   기타 1  51  1000   7.0
# 4  의료 업계 종사자       4.0     의학  31    10   2.0

# %%
# {idx : job for idx, job in enumerate(test_df.직업.unique())}

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              40000 non-null  object
#  1   성별              40000 non-null  object
#  2   차량 소유 여부        40000 non-null  int64
#  3   부동산 소유 여부       40000 non-null  int64
#  4   자녀 수            40000 non-null  int64
#  5   연간 수입           40000 non-null  float64
#  6   수입 유형           40000 non-null  object
#  7   최종 학력           40000 non-null  object
#  8   결혼 여부           40000 non-null  object
#  9   주거 형태           40000 non-null  object
#  10  거주지 인구 비율       40000 non-null  float64
#  11  휴대전화 소유 여부      40000 non-null  int64
#  12  업무용 휴대전화 소유 여부  40000 non-null  int64
#  13  이메일 소유 여부       40000 non-null  int64
#  14  직업              40000 non-null  object
#  15  가족 구성원 수        40000 non-null  float64
#  16  산업군             40000 non-null  object
#  17  나이              40000 non-null  int64
#  18  근속연수            40000 non-null  int64
#  19  가입연수            40000 non-null  float64
# dtypes: float64(4), int64(8), object(8)
# memory usage: 6.1+ MB

# %% [markdown]
# ---

# %%
sample_submission = pd.read_csv("sample_submission.csv")

# %%
sample_submission
# Out:
#                ID  TARGET
# 0      TEST_00000       0
# 1      TEST_00001       0
# 2      TEST_00002       0
# 3      TEST_00003       0
# 4      TEST_00004       0
# ...           ...     ...
# 39995  TEST_39995       0
# 39996  TEST_39996       0
# 39997  TEST_39997       0
# 39998  TEST_39998       0
# 39999  TEST_39999       0
#
# [40000 rows x 2 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## 데이터 전처리

# %% [markdown]
# 데이터 전처리 단계에서는 수치형 데이터의 정규화, 범주형 데이터의 원-핫 인코딩, 결측치 처리 등을 수행합니다. 대출등급이 타겟 변수이므로, 이를 제외한 다른 특성들을 입력 변수로 사용할 것입니다.

# %%
# 범주형 데이터와 수치형 데이터 분리
categorical_cols = train_df.select_dtypes(include=['object']).columns
numeric_cols = train_df.select_dtypes(exclude=['object']).columns

# %%
categorical_cols
# Out:
# Index(['ID', '성별', '수입 유형', '최종 학력', '결혼 여부', '주거 형태', '직업', '산업군'], dtype='object')

# %%
numeric_cols
# Out:
# Index(['TARGET', '차량 소유 여부', '부동산 소유 여부', '자녀 수', '연간 수입', '거주지 인구 비율',
#        '휴대전화 소유 여부', '업무용 휴대전화 소유 여부', '이메일 소유 여부', '가족 구성원 수', '나이', '근속연수',
#        '가입연수'],
#       dtype='object')

# %%
categorical_cols = [
    '성별', '수입 유형', '최종 학력', '결혼 여부', '주거 형태', '직업', '산업군'
]

# %%
train_df[categorical_cols]
# Out:
#        성별  수입 유형      최종 학력 결혼 여부     주거 형태       직업   산업군
# 0      여성  연금수령자    고등학교 졸업    기혼  주택 / 아파트  Unknown  기타 1
# 1      남성    근로자  대학교 졸업 이상    기혼  주택 / 아파트      기술직  사업 1
# 2      여성    근로자    고등학교 졸업    기혼  주택 / 아파트   단순 노동자  사업 0
# 3      여성     기타    고등학교 졸업    기혼  주택 / 아파트  Unknown  산업 4
# 4      여성    근로자    고등학교 졸업    기혼  주택 / 아파트  Unknown  사업 2
# ...    ..    ...        ...   ...       ...      ...   ...
# 59995  여성  연금수령자    고등학교 졸업    미혼  주택 / 아파트  Unknown  기타 1
# 59996  남성    근로자    고등학교 졸업    기혼  주택 / 아파트      운전자   자영업
# 59997  여성    근로자  대학교 졸업 이상    미혼  주택 / 아파트  Unknown    은행
# 59998  여성    근로자    고등학교 졸업    사별  주택 / 아파트   핵심 노동자   우체부
# 59999  남성    근로자    고등학교 졸업    미혼  주택 / 아파트   핵심 노동자    경찰
#
# [60000 rows x 7 columns]

# %%
numeric_cols = [
    '차량 소유 여부', '부동산 소유 여부', '자녀 수', '연간 수입', '거주지 인구 비율', '휴대전화 소유 여부', '업무용 휴대전화 소유 여부', '이메일 소유 여부', '가족 구성원 수', '나이', '근속연수','가입연수'
]

# %%
train_df[numeric_cols]
# Out:
#        차량 소유 여부  부동산 소유 여부  자녀 수       연간 수입  거주지 인구 비율  휴대전화 소유 여부  \
# 0             1          1     2  18054000.0   0.004960           1
# 1             1          0     0  59472000.0   0.018029           1
# 2             0          1     0  29736000.0   0.010500           1
# 3             1          0     1  38232000.0   0.004849           1
# 4             0          1     0  26550000.0   0.025164           1
# ...         ...        ...   ...         ...        ...         ...
# 59995         0          1     0  15930000.0   0.014520           1
# 59996         1          1     0  53100000.0   0.010032           1
# 59997         0          0     0  47790000.0   0.019101           1
# 59998         1          1     0  29736000.0   0.015221           1
# 59999         0          1     0  31860000.0   0.009334           1
#
#        업무용 휴대전화 소유 여부  이메일 소유 여부  가족 구성원 수  나이  근속연수  가입연수
# 0                   0          0       4.0  39  1000  23.0
# 1                   1          0       2.0  45     4  16.0
# 2                   1          0       2.0  32     3   9.0
# 3                   1          0       3.0  34     6  12.0
# 4                   1          0       2.0  38     0   4.0
# ...               ...        ...       ...  ..   ...   ...
# 59995               0          0       1.0  60  1000  29.0
# 59996               1          0       2.0  42     1   1.0
# 59997               1          0       1.0  26     1   7.0
# 59998               1          0       1.0  50    21  16.0
# 59999               1          0       1.0  30     7  15.0
#
# [60000 rows x 12 columns]

# %% [markdown]
# ### 모델을 훈련하기 위해 선택한 train_test_split

# %%
train, valid = train_test_split(train_df, 
                                test_size=0.1, 
                                random_state=42,
                                stratify=train_df.TARGET)

# %% [markdown]
# ### 수치형 데이터 정규화

# %% [markdown]
# ### fit

# %%
scaler = StandardScaler()
scaler.fit(train[numeric_cols])
# Out:
# StandardScaler()

# %%
scaler.mean_
# Out:
# array([3.37833333e-01, 7.08759259e-01, 4.09666667e-01, 3.98397315e+07,
#        2.08924958e-02, 9.99981481e-01, 8.12092593e-01, 5.61851852e-02,
#        2.15385185e+00, 4.40158704e+01, 1.92867944e+02, 1.32642963e+01])

# %%
scaler.scale_
# Out:
# array([4.72971429e-01, 4.54334207e-01, 7.19405027e-01, 2.50002191e+07,
#        1.38438781e-02, 4.30327498e-03, 3.90638213e-01, 2.30278983e-01,
#        9.04595252e-01, 1.18450016e+01, 3.88249254e+02, 9.73269591e+00])

# %% [markdown]
# ### transform

# %%
train_scaled_numeric = scaler.transform(train[numeric_cols])
valid_scaled_numeric = scaler.transform(valid[numeric_cols])
test_scaled_numeric = scaler.transform(test_df[numeric_cols])

# %%
print(train_scaled_numeric.shape)
print(valid_scaled_numeric.shape)
print(test_scaled_numeric.shape)
# Out:
# (54000, 12)
# (6000, 12)
# (40000, 12)

# %% [markdown]
# ### 범주형 데이터 원-핫 인코딩

# %%
train[categorical_cols]
# Out:
#        성별  수입 유형      최종 학력 결혼 여부     주거 형태       직업   산업군
# 1310   여성    근로자    고등학교 졸업    기혼  주택 / 아파트   핵심 노동자    농업
# 54525  여성    근로자  대학교 졸업 이상    기혼  주택 / 아파트      회계사    건설
# 31892  여성  연금수령자    고등학교 졸업    미혼  주택 / 아파트  Unknown  기타 1
# 4075   남성     기타    고등학교 졸업    기혼  주택 / 아파트  Unknown    보안
# 16984  여성    근로자    고등학교 졸업    기혼  주택 / 아파트   핵심 노동자   유치원
# ...    ..    ...        ...   ...       ...      ...   ...
# 5072   여성     기타    고등학교 졸업    기혼  주택 / 아파트   핵심 노동자   자영업
# 30488  여성    근로자    고등학교 졸업    기혼  주택 / 아파트   핵심 노동자   유치원
# 59442  여성     기타    고등학교 졸업    기혼  주택 / 아파트      기술직  산업 0
# 3677   여성     기타  대학교 졸업 이상    기혼  주택 / 아파트      회계사  사업 2
# 25312  남성  연금수령자  대학교 졸업 이상   사실혼    아파트 임대  Unknown  기타 1
#
# [54000 rows x 7 columns]

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '1.3.2'

# %%
encoder = OneHotEncoder(sparse_output=False)
encoder.fit(train[categorical_cols])
# Out:
# OneHotEncoder(sparse_output=False)

# %%
train_encoded_categorical_df = encoder.transform(train[categorical_cols])

# %%
train_encoded_categorical_df = encoder.transform(train[categorical_cols])
valid_encoded_categorical_df = encoder.transform(valid[categorical_cols])
test_encoded_categorical_df = encoder.transform(test_df[categorical_cols])

# %%
print(train_encoded_categorical_df.shape)
print(valid_encoded_categorical_df.shape)
print(test_encoded_categorical_df.shape)
# Out:
# (54000, 98)
# (6000, 98)
# (40000, 98)

# %% [markdown]
# ---

# %%
train_x = np.concatenate([train_scaled_numeric, train_encoded_categorical_df], axis=1)
valid_x = np.concatenate([valid_scaled_numeric, valid_encoded_categorical_df], axis=1)
test_x = np.concatenate([test_scaled_numeric, test_encoded_categorical_df], axis=1)

# %%
print(train_x.shape)
print(valid_x.shape)
print(test_x.shape)
# Out:
# (54000, 110)
# (6000, 110)
# (40000, 110)

# %%
train_y = np.array(train.TARGET).reshape(-1, 1)
valid_y = np.array(valid.TARGET).reshape(-1, 1)

# %%
print(train_y.shape)
print(valid_y.shape)
# Out:
# (54000, 1)
# (6000, 1)

# %%
# 직군 - 데이분석 / CRM / 마케팅
# 업종 - 제조, 금융, 유통, IT(판교)

# %% [markdown]
# ---

# %% [markdown]
# # Model 빌드하기

# %% [markdown]
# ## 1.  Sequential API

# %% [markdown]
# * 가장 간단하고 쉬운 방법입니다.
# * 모델이 순차적인 층(layer)의 스택으로 구성될 때 사용하기 좋습니다.
# * 복잡한 모델을 만드는 데에는 제한이 있습니다 (예: 다중 입력이나 출력, 층 간의 복잡한 연결 등).

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
sequential_model = Sequential([
    Dense(1024, activation='relu', input_shape=(110, )),
    Dropout(0.2),
    Dense(1, activation='sigmoid')
])

# %%
sequential_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                         loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
                         metrics="accuracy")

# %%
sequential_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 1024)              113664
#
#  dropout_7 (Dropout)         (None, 1024)              0
#
#  dense_15 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 114,689
# Trainable params: 114,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(sequential_model, show_shapes=True, show_dtype=True, show_layer_names=True, expand_nested=True, show_layer_activations=True, rankdir="LR")

# %% [markdown]
# ---

# %% [markdown]
# ## 2.  Sequential API

# %% [markdown]
# * TensorFlow의 Sequential 모델은 층을 순차적으로 쌓아 모델을 만드는 간단하고 직관적인 방법을 제공합니다.
# * 이 방법은 각 층이 순차적으로 입력과 출력을 연결하는 경우에 적합합니다.
# * Sequential 모델을 생성하고 층을 추가하는 방식은 두 가지가 있습니다: 모델을 정의할 때 층을 리스트로 전달하는 방법과 add 메서드를 사용하는 방법입니다.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
# 1. Sequential 모델 인스턴스 생성
add_model = Sequential()

# 2. 층 추가
add_model.add(Dense(1024, activation='relu', input_shape=(110, )))
add_model.add(Dropout(0.2))
add_model.add(Dense(1, activation='sigmoid'))

# 3. 모델 컴파일
add_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                  loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
                  metrics="accuracy")

# %%
add_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 1024)              113664
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_3 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 114,689
# Trainable params: 114,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(add_model, show_shapes=True, show_dtype=True, show_layer_names=True, expand_nested=True, show_layer_activations=True, rankdir="LR")

# %% [markdown]
# ---

# %% [markdown]
# ## Functional API

# %% [markdown]
# * 좀 더 복잡한 모델을 구성하는 데 사용됩니다.
# * 다중 입력, 다중 출력, 공유 층, 데이터 흐름의 비순차적 경로 등을 다룰 수 있습니다.
# * 각 층은 호출 가능하며, 이전 층의 출력을 다음 층의 입력으로 사용합니다.

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout

# %%
inputs = Input(shape=(110,))

x = Dense(1024, activation='relu')(inputs)
x = Dropout(0.2)(x)

outputs = Dense(1, activation='sigmoid')(x)

# %%
functional_model = Model(inputs=inputs, outputs=outputs)

# %%
functional_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                         loss=tf.keras.losses.BinaryCrossentropy(),
                         metrics="accuracy")

# %%
functional_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 110)]             0
#
#  dense_4 (Dense)             (None, 1024)              113664
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_5 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 114,689
# Trainable params: 114,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(functional_model, show_shapes=True, show_dtype=True, show_layer_names=True, expand_nested=True, show_layer_activations=True, rankdir="LR")

# %% [markdown]
# ---

# %% [markdown]
# ## Model Subclassing

# %% [markdown]
# * 가장 유연한 방법으로, 사용자 정의 모델을 만들 때 사용됩니다.
# * Model 클래스를 상속받아 __init__ 메서드에서 층을 정의하고, call 메서드에서 순전파를 구현합니다.
# * 복잡한 모델과 사용자 정의 동작을 쉽게 구현할 수 있습니다.

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout

# %%
class MyModel(Model): 
    
    def __init__(self):
        super(MyModel, self).__init__()
        
        self.dense = Dense(1024, activation='relu')
        self.dropout = Dropout(0.2)
        self.logits = Dense(1, activation='sigmoid')

    def call(self, inputs):
        x = self.dense(inputs)
        x = self.dropout(x)
        out = self.logits(x)
        return out

subclassing_model = MyModel()
# Out:
# WARNING:tensorflow:From C:\Users\Owner\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
loss_fn = tf.keras.losses.BinaryCrossentropy(from_logits=False)

# %% [markdown]
# ---

# %%
subclassing_model.build(input_shape=(None, 110))

# %%
subclassing_model.summary()
# Out:
# Model: "my_model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            multiple                  113664
#
#  dropout_6 (Dropout)         multiple                  0
#
#  dense_13 (Dense)            multiple                  1025
#
# =================================================================
# Total params: 114,689
# Trainable params: 114,689
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ---

# %%
tf.keras.utils.plot_model(subclassing_model, show_shapes=True, show_dtype=True, show_layer_names=True, expand_nested=True, show_layer_activations=True, rankdir="LR")

# %% [markdown]
# ---

# %% [markdown]
# # 모델 학습

# %% [markdown]
# ## 1.  Sequential API

# %%
sequential_history = sequential_model.fit(x=train_x, y=train_y,  validation_data=(valid_x, valid_y), epochs=10)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 5s 2ms/step - loss: 0.3337 - accuracy: 0.8928 - val_loss: 0.3309 - val_accuracy: 0.8928
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3299 - accuracy: 0.8929 - val_loss: 0.3280 - val_accuracy: 0.8928
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3281 - accuracy: 0.8929 - val_loss: 0.3316 - val_accuracy: 0.8927
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3264 - accuracy: 0.8928 - val_loss: 0.3295 - val_accuracy: 0.8928
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3243 - accuracy: 0.8928 - val_loss: 0.3321 - val_accuracy: 0.8928
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3221 - accuracy: 0.8929 - val_loss: 0.3323 - val_accuracy: 0.8923
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3190 - accuracy: 0.8929 - val_loss: 0.3330 - val_accuracy: 0.8925
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3154 - accuracy: 0.8933 - val_loss: 0.3349 - val_accuracy: 0.8922
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3117 - accuracy: 0.8932 - val_loss: 0.3377 - val_accuracy: 0.8917
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3076 - accuracy: 0.8939 - val_loss: 0.3415 - val_accuracy: 0.8910

# %%
plt.figure(figsize=(20, 3))
plt.plot(sequential_history.history['loss'], 'b-', label='loss')
plt.plot(sequential_history.history['val_loss'], 'r--', label='val_loss')
plt.show()

# %% [markdown]
# ## 2.  Sequential API

# %%
add_history = add_model.fit(x=train_x, y=train_y,  validation_data=(valid_x, valid_y), epochs=10)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3339 - accuracy: 0.8921 - val_loss: 0.3340 - val_accuracy: 0.8928
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3297 - accuracy: 0.8929 - val_loss: 0.3296 - val_accuracy: 0.8928
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3285 - accuracy: 0.8929 - val_loss: 0.3330 - val_accuracy: 0.8928
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3268 - accuracy: 0.8929 - val_loss: 0.3311 - val_accuracy: 0.8927
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3246 - accuracy: 0.8928 - val_loss: 0.3298 - val_accuracy: 0.8927
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3219 - accuracy: 0.8928 - val_loss: 0.3331 - val_accuracy: 0.8928
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3191 - accuracy: 0.8927 - val_loss: 0.3342 - val_accuracy: 0.8927
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3154 - accuracy: 0.8932 - val_loss: 0.3349 - val_accuracy: 0.8922
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3116 - accuracy: 0.8933 - val_loss: 0.3380 - val_accuracy: 0.8912
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3075 - accuracy: 0.8938 - val_loss: 0.3423 - val_accuracy: 0.8908

# %%
plt.figure(figsize=(20, 3))
plt.plot(add_history.history['loss'], 'b-', label='loss')
plt.plot(add_history.history['val_loss'], 'r--', label='val_loss')
plt.show()

# %% [markdown]
# ## 3. Functional API

# %%
functional_history = functional_model.fit(x=train_x, y=train_y,  validation_data=(valid_x, valid_y), epochs=10)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3343 - accuracy: 0.8926 - val_loss: 0.3299 - val_accuracy: 0.8928
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3298 - accuracy: 0.8929 - val_loss: 0.3321 - val_accuracy: 0.8928
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3284 - accuracy: 0.8929 - val_loss: 0.3348 - val_accuracy: 0.8928
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3271 - accuracy: 0.8928 - val_loss: 0.3316 - val_accuracy: 0.8927
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3248 - accuracy: 0.8929 - val_loss: 0.3296 - val_accuracy: 0.8927
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3224 - accuracy: 0.8928 - val_loss: 0.3330 - val_accuracy: 0.8923
# Epoch 7/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3187 - accuracy: 0.8929 - val_loss: 0.3359 - val_accuracy: 0.8908
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3152 - accuracy: 0.8930 - val_loss: 0.3383 - val_accuracy: 0.8912
# Epoch 9/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3116 - accuracy: 0.8935 - val_loss: 0.3415 - val_accuracy: 0.8902
# Epoch 10/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3077 - accuracy: 0.8936 - val_loss: 0.3395 - val_accuracy: 0.8915

# %%
plt.figure(figsize=(20, 3))
plt.plot(functional_history.history['loss'], 'b-', label='loss')
plt.plot(functional_history.history['val_loss'], 'r--', label='val_loss')
plt.show()

# %% [markdown]
# ## Model Subclassing

# %%
from sklearn.utils import gen_batches, shuffle

# %%
total_epoch = 10
batch_size = 128

# %%
for i in range(10):
    for j in range(422):
        trining()

# %%
# 422번 

# train_x[0    : 128]
# train_x[128  : 128*2]
# train_x[128*2: 128*3]
# ..
# ..
# ..
# train_x[128*421: 128*422]

# %%
train_x.shape
# Out:
# (54000, 110)

# %%
train_batches = list(gen_batches(len(train_x), batch_size))

# %%
train_loss = tf.keras.metrics.Mean()
valid_loss = tf.keras.metrics.Mean()

train_acc = tf.keras.metrics.BinaryAccuracy()
valid_acc = tf.keras.metrics.BinaryAccuracy()

train_auc = tf.keras.metrics.AUC()
valid_auc = tf.keras.metrics.AUC()

# %%
for epoch in range(total_epoch):
    
    train_loss.reset_state()
    valid_loss.reset_state()
    
    ####################################################################################################
    # training
    (shuffle_x, shuffle_y) = shuffle(train_x, train_y)
    
    for batch in train_batches:
        
        batch_x = shuffle_x[batch]
        batch_y = shuffle_y[batch]
        
        with tf.GradientTape() as tape:
            logits = subclassing_model(batch_x)
            loss = loss_fn(batch_y, logits)

        gradients = tape.gradient(loss, subclassing_model.trainable_variables)
        optimizer.apply_gradients(zip(gradients, subclassing_model.trainable_variables))
        
        train_loss.update_state(loss)
        train_acc.update_state(batch_y, logits)
        train_auc.update_state(batch_y, logits)
        
    ####################################################################################################
    # history
    logits = subclassing_model.predict(valid_x, verbose=False)
    loss = loss_fn(valid_y, logits)
    valid_loss.update_state(loss)
    valid_acc.update_state(valid_y, logits)
    valid_auc.update_state(valid_y, logits)
    
    msg = "epoch: {:>5d} - loss: {:>.5f} - accuracy: {:>.3%} - auc: {:>.3%} - val_loss: {:>.5f} - val_accuracy: {:>.3%} - val_auc: {:>.3%}"
    print(msg.format(epoch, 
                     train_loss.result().numpy(), train_acc.result().numpy(), train_auc.result().numpy(), 
                     valid_loss.result().numpy(), valid_acc.result().numpy(), valid_auc.result().numpy()))
# Out:
# epoch:     0 - loss: 0.33483 - accuracy: 89.185% - auc: 62.071% - val_loss: 0.32924 - val_accuracy: 89.283% - val_auc: 63.853%
# epoch:     1 - loss: 0.32763 - accuracy: 89.236% - auc: 63.420% - val_loss: 0.32886 - val_accuracy: 89.283% - val_auc: 63.820%
# epoch:     2 - loss: 0.32574 - accuracy: 89.252% - auc: 64.151% - val_loss: 0.33117 - val_accuracy: 89.283% - val_auc: 63.455%
# epoch:     3 - loss: 0.32383 - accuracy: 89.261% - auc: 64.738% - val_loss: 0.32912 - val_accuracy: 89.283% - val_auc: 63.409%
# epoch:     4 - loss: 0.32229 - accuracy: 89.265% - auc: 65.221% - val_loss: 0.32982 - val_accuracy: 89.283% - val_auc: 63.377%
# epoch:     5 - loss: 0.31923 - accuracy: 89.268% - auc: 65.749% - val_loss: 0.33106 - val_accuracy: 89.278% - val_auc: 63.290%
# epoch:     6 - loss: 0.31704 - accuracy: 89.273% - auc: 66.236% - val_loss: 0.33514 - val_accuracy: 89.276% - val_auc: 63.027%
# epoch:     7 - loss: 0.31298 - accuracy: 89.278% - auc: 66.810% - val_loss: 0.33528 - val_accuracy: 89.269% - val_auc: 62.899%
# epoch:     8 - loss: 0.30878 - accuracy: 89.287% - auc: 67.391% - val_loss: 0.33781 - val_accuracy: 89.259% - val_auc: 62.862%
# epoch:     9 - loss: 0.30498 - accuracy: 89.301% - auc: 67.995% - val_loss: 0.33866 - val_accuracy: 89.242% - val_auc: 62.740%

# %% [markdown]
# ---

# %% [markdown]
# ## Model Subclassing - tf.function

# %%
class MyModel(Model):
    
    def __init__(self):
        super(MyModel, self).__init__()
        
        self.dense = Dense(1024, activation='relu')
        self.dropout = Dropout(0.2)
        self.logits = Dense(1, activation='sigmoid')

    def call(self, inputs, training=False):
        
        x = self.dense(inputs)
        x = self.dropout(x, training=training)
        out = self.logits(x)
        return out

training_model = MyModel()

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
loss_fn = tf.keras.losses.BinaryCrossentropy(from_logits=False)

# %%
@tf.function
def train_step(features, targets):

    with tf.GradientTape() as tape:
        logits = training_model(features, training=True)
        loss = loss_fn(targets, logits)

    gradients = tape.gradient(loss, training_model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, training_model.trainable_variables))

    train_loss.update_state(loss)
    train_acc.update_state(targets, logits)
    train_auc.update_state(targets, logits)

# %%
@tf.function
def test_step(features, targets):
    
    logits = training_model(features, training=False)
    loss = loss_fn(targets, logits)
    valid_loss.update_state(loss)
    valid_acc.update_state(targets, logits)
    valid_auc.update_state(targets, logits)

# %%
for epoch in range(total_epoch):
    
    train_loss.reset_state()
    valid_loss.reset_state()
    
    (shuffle_x, shuffle_y) = shuffle(train_x, train_y)
    
    for batch in train_batches:
        batch_x = shuffle_x[batch]
        batch_y = shuffle_y[batch]
        train_step(batch_x, batch_y)
    
    test_step(valid_x, valid_y)
    
    msg = "epoch: {:>5d} - loss: {:>.5f} - accuracy: {:>.3%} - auc: {:>.3%} - val_loss: {:>.5f} - val_accuracy: {:>.3%} - val_auc: {:>.3%}"
    print(msg.format(epoch, 
                     train_loss.result().numpy(), train_acc.result().numpy(), train_auc.result().numpy(), 
                     valid_loss.result().numpy(), valid_acc.result().numpy(), valid_auc.result().numpy()))
# Out:
# epoch:     0 - loss: 0.33593 - accuracy: 89.275% - auc: 67.485% - val_loss: 0.32832 - val_accuracy: 89.245% - val_auc: 62.809%
# epoch:     1 - loss: 0.32837 - accuracy: 89.276% - auc: 67.234% - val_loss: 0.32821 - val_accuracy: 89.249% - val_auc: 62.912%
# epoch:     2 - loss: 0.32656 - accuracy: 89.277% - auc: 67.085% - val_loss: 0.32899 - val_accuracy: 89.251% - val_auc: 62.999%
# epoch:     3 - loss: 0.32470 - accuracy: 89.277% - auc: 67.009% - val_loss: 0.33070 - val_accuracy: 89.254% - val_auc: 62.995%
# epoch:     4 - loss: 0.32344 - accuracy: 89.278% - auc: 66.981% - val_loss: 0.32952 - val_accuracy: 89.254% - val_auc: 63.036%
# epoch:     5 - loss: 0.32119 - accuracy: 89.279% - auc: 67.013% - val_loss: 0.33353 - val_accuracy: 89.255% - val_auc: 63.030%
# epoch:     6 - loss: 0.31920 - accuracy: 89.280% - auc: 67.093% - val_loss: 0.33358 - val_accuracy: 89.253% - val_auc: 63.006%
# epoch:     7 - loss: 0.31698 - accuracy: 89.281% - auc: 67.212% - val_loss: 0.33153 - val_accuracy: 89.253% - val_auc: 63.018%
# epoch:     8 - loss: 0.31435 - accuracy: 89.283% - auc: 67.368% - val_loss: 0.33386 - val_accuracy: 89.249% - val_auc: 63.016%
# epoch:     9 - loss: 0.31085 - accuracy: 89.287% - auc: 67.568% - val_loss: 0.33448 - val_accuracy: 89.247% - val_auc: 62.991%

# %% [markdown]
# ---

# %% [markdown]
# # 추론 수행하기

# %% [markdown]
# ### sequential_model

# %%
sequential_pred = sequential_model.predict(valid_x)
# Out:
# 188/188 [==============================] - 0s 820us/step

# %%
sequential_pred
# Out:
# array([[0.0564385 ],
#        [0.06094439],
#        [0.0177617 ],
#        ...,
#        [0.15828264],
#        [0.09777553],
#        [0.15736923]], dtype=float32)

# %% [markdown]
# ### add_model

# %%
add_pred = add_model.predict(valid_x)
# Out:
# 188/188 [==============================] - 0s 769us/step

# %%
add_pred
# Out:
# array([[0.06117534],
#        [0.1172301 ],
#        [0.02458549],
#        ...,
#        [0.15842646],
#        [0.1125242 ],
#        [0.10492834]], dtype=float32)

# %% [markdown]
# ### functional_model

# %%
functional_pred = functional_model.predict(valid_x)
# Out:
# 188/188 [==============================] - 0s 777us/step

# %%
functional_pred
# Out:
# array([[0.04064612],
#        [0.10070081],
#        [0.04664804],
#        ...,
#        [0.14938709],
#        [0.16792236],
#        [0.21384887]], dtype=float32)

# %% [markdown]
# ### subclassing_model

# %%
subclassing_pred = subclassing_model.predict(valid_x)
# Out:
# 188/188 [==============================] - 1s 3ms/step

# %%
subclassing_pred
# Out:
# array([[0.02044423],
#        [0.08065876],
#        [0.17602965],
#        ...,
#        [0.17159978],
#        [0.15695463],
#        [0.11903639]], dtype=float32)

# %% [markdown]
# ### training_model

# %%
training_pred = training_model(valid_x, training=False)

# %%
training_pred
# Out:
# <tf.Tensor: shape=(6000, 1), dtype=float32, numpy=
# array([[0.06370021],
#        [0.13071314],
#        [0.10394002],
#        ...,
#        [0.10710616],
#        [0.12922627],
#        [0.14848714]], dtype=float32)>

# %% [markdown]
# ---

# %%
predict_df = pd.DataFrame({
    "y_true" : valid_y.reshape(-1),
    "y_score" : training_pred.numpy().reshape(-1),
    "y_pred" : [1 if i >= 0.5 else 0 for i in training_pred.numpy().reshape(-1)],
})
predict_df

# %%
accuracy = accuracy_score(predict_df.y_true, predict_df.y_pred)
f1 = f1_score(predict_df.y_true, predict_df.y_pred)
roc_auc = roc_auc_score(predict_df.y_true, predict_df.y_score)

# %%
print("acc : {:>.3%}".format(accuracy))
print("f1  : {:>.3%}".format(f1))
print("auc : {:>.3%}".format(roc_auc))

# %%
plt.figure(figsize=(20, 5))
sns.distplot(predict_df.loc[((predict_df["y_true"] == 0)), "y_score"], bins=[i/50. for i in range(51)], color="red")
sns.distplot(predict_df.loc[((predict_df["y_true"] == 1)), "y_score"], bins=[i/50. for i in range(51)], color="green")
plt.xlim([0, 1])
plt.show()

# %% [markdown]
# # sample_submission

# %%
training_pred = training_model(test_x, training=False)

# %%
training_pred

# %%
sample_submission["TARGET"] = training_pred.numpy()

# %%
sample_submission

# %%
sample_submission

# %%
sample_submission.to_csv('../data/대금연체여부예측/baseline_submit.csv', index=False)

# %% [markdown]
# ---
